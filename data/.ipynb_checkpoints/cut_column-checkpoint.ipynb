# %%
import pandas as pd
import numpy as np
import os

file_name = 'data_raw.xlsx'
new_file_name = 'data.xlsx'

current_dir = os.getcwd()
data_path = os.path.join(current_dir, file_name)
data_save_path = os.path.join(current_dir, new_file_name)

print('file path', data_path)

print('new file path', data_save_path)

raw_data = pd.read_excel(data_path)
data = raw_data[['cat', 'comment']]

data.loc[:, 'creditability'] = ''
data.loc[:, 'content'] = ''
data.loc[:, 'expression'] = ''
# Out:
# file path C:\Users\Pop\Documents\GitHub\utcc_independent_study\data\data_raw.xlsx
# new file path C:\Users\Pop\Documents\GitHub\utcc_independent_study\data\data.xlsx
# C:\Users\Pop\AppData\Local\Temp\ipykernel_14372\3964666387.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'creditability'] = ''
# C:\Users\Pop\AppData\Local\Temp\ipykernel_14372\3964666387.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'content'] = ''
# C:\Users\Pop\AppData\Local\Temp\ipykernel_14372\3964666387.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'expression'] = ''

# %%
raw_data
# Out:
#     products                                        product_url  \
# 0         34  https://shopee.co.th/-%E0%B8%9E%E0%B8%A3%E0%B9...
# 1         34  https://shopee.co.th/-%E0%B8%9E%E0%B8%A3%E0%B9...
# 2         34  https://shopee.co.th/-%E0%B8%9E%E0%B8%A3%E0%B9...
# 3         34  https://shopee.co.th/-%E0%B8%AD%E0%B8%B1%E0%B8...
# 4         34  https://shopee.co.th/-%E0%B8%AD%E0%B8%B1%E0%B8...
# ..       ...                                                ...
# 995        5  https://shopee.co.th/%E2%9C%854.25%E2%9C%85%E3...
# 996        5  https://shopee.co.th/%E2%9C%854.25%E2%9C%85%E3...
# 997        5  https://shopee.co.th/%E2%9C%854.25%E2%9C%85%E3...
# 998        6  https://shopee.co.th/%E0%B8%A5%E0%B8%B3%E0%B9%...
# 999        7  https://shopee.co.th/%E0%B8%A5%E0%B8%94%E0%B8%...
#
#                                           product_name  overall_rate  \
# 0    [พร้อมส่ง] HOCO W35 / W25 / W33 หูฟังครอบหูแบบ...           4.9
# 1    [พร้อมส่ง] HOCO W35 / W25 / W33 หูฟังครอบหูแบบ...           4.9
# 2    [พร้อมส่ง] HOCO W35 / W25 / W33 หูฟังครอบหูแบบ...           4.9
# 3    [อัพเกรด] UGREEN อะแดปเตอร์รับส่งสัญญาณ USB บล...           4.9
# 4    [อัพเกรด] UGREEN อะแดปเตอร์รับส่งสัญญาณ USB บล...           4.9
# ..                                                 ...           ...
# 995  ✅4.25✅【ของแท้ 100%】Marshall Kilburn II 3 สี ma...           5.0
# 996  ✅4.25✅【ของแท้ 100%】Marshall Kilburn II 3 สี ma...           5.0
# 997  ✅4.25✅【ของแท้ 100%】Marshall Kilburn II 3 สี ma...           5.0
# 998  ลำโพงบลูทูธ รุ่น 6.5”v 2 เเพนพาส เบสหนักเเน่นเ...           5.0
# 999  ลดราคา !!!【ประเทศไทย 】 Marshall STOCKWELL II ล...           4.9
#
#              cat                cat_1                   cat_2  \
# 0    หูฟังไร้สาย   Home Entertainment  Earphones & Headphones
# 1    หูฟังไร้สาย   Home Entertainment  Earphones & Headphones
# 2    หูฟังไร้สาย   Home Entertainment  Earphones & Headphones
# 3    หูฟังไร้สาย  Computers & Laptops      Network Components
# 4    หูฟังไร้สาย  Computers & Laptops      Network Components
# ..           ...                  ...                     ...
# 995  ลำโพงบลูทูธ               Shopee      Home Entertainment
# 996  ลำโพงบลูทูธ               Shopee      Home Entertainment
# 997  ลำโพงบลูทูธ               Shopee      Home Entertainment
# 998  ลำโพงบลูทูธ               Shopee      Home Entertainment
# 999  ลำโพงบลูทูธ               Shopee      Home Entertainment
#
#                                  cat_3  favorite       date    timing  \
# 0                             Over-Ear     14200 2023-01-27  20:55:00
# 1                             Over-Ear     14200 2022-12-12  20:55:00
# 2                             Over-Ear     14200 2022-12-16  11:31:00
# 3    Wireless Adapters & Network Cards      3700 2023-02-03  09:21:00
# 4    Wireless Adapters & Network Cards      3700 2023-03-09  04:10:00
# ..                                 ...       ...        ...       ...
# 995                           Speakers        89 2023-01-24  15:47:00
# 996                           Speakers        89 2023-01-19  14:28:00
# 997                           Speakers        89 2023-01-22  13:24:00
# 998                           Speakers        89 2023-04-06  15:10:00
# 999                           Speakers      2600 2022-08-02  10:21:00
#
#      num_like  review_stars                                            comment
# 0           0             1  แย่ เสียงพอใช้ได้แต่ไมค์แย่มากใช้คุยไม่ได้เลยไ...
# 1           2             1  เสียงคุยผ่าน MS Teams ปลายทางบอกว่าอู้อี้ แต่เ...
# 2           0             1  แอดมินแอคทีฟตอบหน่อยค่ะ เห็นแจ้งว่าแอคทีฟ9โมงน...
# 3           0             1  สั่งมาผิดยกเลิกไม่ได้จะตีกลับก้อสงสารขนส่งเลยจ...
# 4           1             1                            ใช้แล้วเด้งรัวๆ หลอนมาก
# ..        ...           ...                                                ...
# 995         1             5  ลำโพงสวยมากๆเลยค่ะ เสียงดี แพ็คของมาก็ดีมากๆค่...
# 996         1             5  ตัดสินใจอยู่นานเลยครับ พอได้รับของก็ประทับใจดี...
# 997         1             5  ได้ของถูกใจ ราคาก็ถูก ส่งของไวมาก  ได้สมดังใจ ...
# 998         1             5          เสียงดีค่ะ เเต่เก็บงานม่ค่อยละเอียดเท่าไร
# 999       111             5              พอใจมาก ใหม่เอี่ยม ของแท้ เชื่อถือได้
#
# [1000 rows x 14 columns]

# %%
cat_count = raw_data['cat'].value_counts()
num_like_count = raw_data['num_like'].value_counts()
star_count = raw_data['review_stars'].value_counts()
name_count, num_like_count, star_count
# Out:
# (หูฟังไร้สาย                208
#  คีย์บอร์ดและเมาส์บลูทูธ    202
#  เครื่องฟอกอากาศ            201
#  สมาร์ทวอทช์                200
#  ลำโพงบลูทูธ                189
#  Name: cat, dtype: int64,
#  0      730
#  1      125
#  2       38
#  3       26
#  4       15
#  5       12
#  6        8
#  8        7
#  9        4
#  7        4
#  13       4
#  14       3
#  10       3
#  34       2
#  35       2
#  117      1
#  12       1
#  15       1
#  37       1
#  18       1
#  121      1
#  30       1
#  89       1
#  49       1
#  19       1
#  22       1
#  31       1
#  97       1
#  11       1
#  16       1
#  41       1
#  111      1
#  Name: num_like, dtype: int64,
#  4    256
#  3    223
#  1    200
#  5    167
#  2    154
#  Name: review_stars, dtype: int64)

# %%
data.to_excel(data_save_path, index=False)
