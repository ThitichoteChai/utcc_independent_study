# %%
# %run data.py
# %run classical_model.py
# Out:
# data_path: C:\Users\Pop\Documents\GitHub\utcc_independent_study\training\..\data\data.xlsx
# model_dir: C:\Users\Pop\Documents\GitHub\utcc_independent_study\training\..\model
# K=1: train_1: 640 | test_1: 160
# K=2: train_2: 640 | test_2: 160
# K=3: train_3: 640 | test_3: 160
# K=4: train_4: 640 | test_4: 160
# K=5: train_5: 640 | test_5: 160
# Validation: val_data: 200

# %%
res_linear, res_svm, res_tree, res_knn = [], [], [], []

for index in range(1, 6):
    train = 'train_' + str(index) 
    test = 'test_' + str(index)
    train = eval(train)
    test = eval(test)

    X_train = train['comment']
    X_test = test['comment']
    y_train = train['score']
    y_test = test['score']
    
    linear_model(X_train, X_test, y_train, y_test, val_data, index)
    svm_model(X_train, X_test, y_train, y_test, val_data, index)
    tree_model(X_train, X_test, y_train, y_test, val_data, index)
    knn_model(X_train, X_test, y_train, y_test, val_data, index)
    
    linear_name = 'linear_model_' + str(index) + '.pkl'
    svm_name = 'svm_model_' + str(index) + '.pkl'
    tree_name = 'tree_model_' + str(index) + '.pkl'
    knn_name = 'knn_model_' + str(index) + '.pkl'
    
    result = evaluate_model(linear_name, val_data)
    res_linear.append(result)
    
    result = evaluate_model(svm_name, val_data)
    res_svm.append(result)
    
    result = evaluate_model(tree_name, val_data)
    res_tree.append(result)
    
    result = evaluate_model(knn_name, val_data)
    res_knn.append(result)
# Out:
# ******************** linear_model_1.pkl ********************)
# train_1, test_1
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Linear Regression MAE on train set: 0.0671
# Linear Regression MAE on test set: 2.0577
# train: 3.786052
# test: 0.000999
# ******************** svm_model_1.pkl ********************)
# train_1, test_1
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVM MAE on train set: 0.3745
# SVM MAE on test set: 1.5683
# train: 4.409820
# test: 0.016954
# ******************** tree_model_1.pkl ********************)
# train_1, test_1
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Decision Tree MAE on train set: 0.2835
# Decision Tree MAE on test set: 1.6971
# train: 1.442295
# test: 0.000998
# ******************** knn_model_1.pkl ********************
# train_1, test_1
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# KNN MAE on train set: 0.1268
# KNN MAE on test set: 1.8602
# train: 1.121003
# test: 0.029920
# linear_model_1.pkl: validation mae: 1.8880
# validation: 0.000000
# svm_model_1.pkl: validation mae: 1.4920
# validation: 0.021940
# tree_model_1.pkl: validation mae: 1.7179
# validation: 0.000000
# knn_model_1.pkl: validation mae: 1.8237
# validation: 0.037898
# ******************** linear_model_2.pkl ********************)
# train_2, test_2
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Linear Regression MAE on train set: 0.0818
# Linear Regression MAE on test set: 1.9817
# train: 0.204454
# test: 0.000000
# ******************** svm_model_2.pkl ********************)
# train_2, test_2
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVM MAE on train set: 0.3601
# SVM MAE on test set: 1.3786
# train: 5.570625
# test: 0.026922
# ******************** tree_model_2.pkl ********************)
# train_2, test_2
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Decision Tree MAE on train set: 0.2272
# Decision Tree MAE on test set: 1.5458
# train: 1.800298
# test: 0.000999
# ******************** knn_model_2.pkl ********************
# train_2, test_2
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# KNN MAE on train set: 0.1158
# KNN MAE on test set: 1.6326
# train: 1.345742
# test: 0.050005
# linear_model_2.pkl: validation mae: 1.9512
# validation: 0.000000
# svm_model_2.pkl: validation mae: 1.5417
# validation: 0.021451
# tree_model_2.pkl: validation mae: 1.8770
# validation: 0.000000
# knn_model_2.pkl: validation mae: 1.8432
# validation: 0.041976
# ******************** linear_model_3.pkl ********************)
# train_3, test_3
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Linear Regression MAE on train set: 0.1256
# Linear Regression MAE on test set: 1.9069
# train: 0.196911
# test: 0.000000
# ******************** svm_model_3.pkl ********************)
# train_3, test_3
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVM MAE on train set: 0.3790
# SVM MAE on test set: 1.4972
# train: 4.798066
# test: 0.019038
# ******************** tree_model_3.pkl ********************)
# train_3, test_3
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Decision Tree MAE on train set: 0.1404
# Decision Tree MAE on test set: 1.5861
# train: 1.545417
# test: 0.000998
# ******************** knn_model_3.pkl ********************
# train_3, test_3
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# KNN MAE on train set: 0.1572
# KNN MAE on test set: 1.7453
# train: 1.137105
# test: 0.035952
# linear_model_3.pkl: validation mae: 1.6824
# validation: 0.000997
# svm_model_3.pkl: validation mae: 1.5221
# validation: 0.024004
# tree_model_3.pkl: validation mae: 1.6897
# validation: 0.000998
# knn_model_3.pkl: validation mae: 1.8042
# validation: 0.041977
# ******************** linear_model_4.pkl ********************)
# train_4, test_4
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Linear Regression MAE on train set: 0.1630
# Linear Regression MAE on test set: 1.8945
# train: 0.220049
# test: 0.000997
# ******************** svm_model_4.pkl ********************)
# train_4, test_4
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVM MAE on train set: 0.3799
# SVM MAE on test set: 1.6200
# train: 5.570478
# test: 0.019946
# ******************** tree_model_4.pkl ********************)
# train_4, test_4
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Decision Tree MAE on train set: 0.2954
# Decision Tree MAE on test set: 1.9380
# train: 1.625843
# test: 0.000998
# ******************** knn_model_4.pkl ********************
# train_4, test_4
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# KNN MAE on train set: 0.1587
# KNN MAE on test set: 1.7712
# train: 1.223041
# test: 0.044922
# linear_model_4.pkl: validation mae: 1.6319
# validation: 0.000000
# svm_model_4.pkl: validation mae: 1.5298
# validation: 0.032523
# tree_model_4.pkl: validation mae: 1.6544
# validation: 0.000000
# knn_model_4.pkl: validation mae: 1.8052
# validation: 0.046875
# ******************** linear_model_5.pkl ********************)
# train_5, test_5
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Linear Regression MAE on train set: 0.0036
# Linear Regression MAE on test set: 1.8213
# train: 0.241992
# test: 0.001995
# ******************** svm_model_5.pkl ********************)
# train_5, test_5
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVM MAE on train set: 0.3485
# SVM MAE on test set: 1.6467
# train: 5.037180
# test: 0.020974
# ******************** tree_model_5.pkl ********************)
# train_5, test_5
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Decision Tree MAE on train set: 0.1396
# Decision Tree MAE on test set: 1.9260
# train: 1.399960
# test: 0.000000
# ******************** knn_model_5.pkl ********************
# train_5, test_5
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# KNN MAE on train set: 0.0962
# KNN MAE on test set: 1.9192
# train: 1.092876
# test: 0.028980
# linear_model_5.pkl: validation mae: 1.7283
# validation: 0.000000
# svm_model_5.pkl: validation mae: 1.5594
# validation: 0.021964
# tree_model_5.pkl: validation mae: 1.7343
# validation: 0.000998
# knn_model_5.pkl: validation mae: 1.8832
# validation: 0.039958

# %%
res_linear[0]
# Out:
#                                                comment  actual  predicted
# 78   การจัดส่งค่อนข้างช้ามากๆค่ะ สั่งตั้งแต่วันที่1...       8   9.000000
# 88   ได้รับสินค้าแล้ว รอของค่อนข้างนาน แต่ก็เข้าใจว...       8   9.000000
# 787  สินค้าจัดส่งเร็วค่ะ ทุกอย่างอยู่ในสภาพดี เชื่อ...       9   9.000000
# 527  ใส่ซองพลาสติกมา แกะออกดูใจหายแว๊บบบบบบ ไมเม้าท...       8   9.000000
# 924  จัดส่งรวดเร็ว สวยงามมินิมอล ราคาไม่แพงค่ะ เสีย...       8   9.000000
# ..                                                 ...     ...        ...
# 235                                        สินค้าชำรุด       3   0.255935
# 649                                 ตั้งเวลาอะไรไม่ได้       2   0.065342
# 54                                   สินค้ารอนานจากจีน       3   0.000000
# 23                                    ไมค์ใช้งานไม่ได้       3   0.000000
# 247                                    -ปานกลาง ใช้ได้       1   0.000000
#
# [200 rows x 3 columns]

# %%
for index, row in result.iterrows():
    print(f"comment: {row['comment']}")
    print(f"predicted: {row['predicted']}")
    print('')
# Out:
# comment: อายุแบตเตอร์รี่ยาวนานพอได้ ติดแผ่นกันรอยมาด้วย เชื่อมต่อกับ mobile phone แล้ว เสียงออกมาทาง smart watch ด้วย น่าจะใช้โทร+รับโทรศัพท์ได้ด้วย
# actual: 6
# predicted: 8.291153418611627
#
# comment: สั้งไป 3 วันได้ แต่สินค้ามีรอยหยัก กล่องไม่บุบสลาย เป็นที่สินค้าเอง พอรับได้
# actual: 4
# predicted: 8.100038019736663
#
# comment: ชอบมากสีนี้ ออกครีมเหมือนนม เสียงเบสดีมาก เพราะมาก คุ้มค่ามาก ราคาไม่แพงเกินไป เลิฟสุดสุดค่ะ 💓
# actual: 9
# predicted: 8.097011659549084
#
# comment: ได้รับคีย์บอร์ดไร้สายมาแล้วครับ แนวใหม่มากๆ สวยมาก ใช้งานสะดวกมาก คีย์บอร์ดเงียบมาก แทบไม่ได้ยินเสียง ราคาไม่แพง แนะนำครับ
# actual: 9
# predicted: 8.000476913781835
#
# comment: ร้านส่งไว แพ็กสินค้ามาก ดีมากกกกก ของแท้นะเท่าที่ดู ราคาถูกด้วยคุ้มค่าเลย สั่งอีกแน่นอนนนน กินแบ้วผิวใส ชอบบๆๆๆๆ
# actual: 0
# predicted: 7.906563540522084
#
# comment: ไม่สามารถกดซัตเตอร์กล้องถ่ายรูปผ่านนาฬิกาได้ บริการหลังการขายไม่ค่อยโอเค ทักไปถามบอกให้รอๆๆ  พอผ่านไปหลายวันทวงถามอีก บอกให้ส่งนาฬิกามาเช็ค
# actual: 9
# predicted: 7.905025763404759
#
# comment: ได้รับสินค้าแล้ว รอของค่อนข้างนาน แต่ก็เข้าใจว่ามาจากต่างประเทศ หูฟังข้างนึงไม่ค่อยได้ยินเสียง ตัวกล่องมีรอยข่วนยาว ๆ ไม่กระทบอะไร แต่เห็นแล้วขัดใจ โดยรวมก็ดีแหละ ราคาสมเหตุ สมผลมั้ง
# actual: 8
# predicted: 7.904311247513785
#
# comment: ตามราคาน้ำหนักนาฬิกาค่อนข้างเบา หน้าจอมีให้เลือกหลายแบบ เมนูมีนิดเดียว จับจังหวะการเต้นของหัวใจไม่ค่อยติด มีเกมในเครื่อง 2 เกม เพลงเชื่อมได้แค่ใน app Music โหลดแอพเพิ่มไม่ได้ กล้องมีแค่กดชัตเตอร์ไม่มีรูปตัวอย่างให้ดู แจ้งเตือนตัวหนังสือคอมพิวเตอร์มาก โดยรวมถือว่าสมราคา
# actual: 9
# predicted: 7.795618236507614
#
# comment: จัดส่งไวมาก สวยดีค่ะ เสียงกำลังดี สำหรับคนมี่ไม่ชอบเสียงทุ้ม เบสหนักแบบเรา แนะนำนะคะ ขนาดน่ารัก ดูทรงคล้ายๆ แอพอตเลยนะ ใส่สบายหู ใช้คุยไม่เท่าไรนะ จะเหมาะกับเอามาฟังเพลงมากกว่า ดีนะ ชอบมากก
# actual: 6
# predicted: 7.719728703757381
#
# comment: คุณภาพสินค้าเสียหาย ปลั๊กไฟฉีกชาด ร้านไม่ตรวจเช็คสินค้าก่อนส่ง แจ้งให้ลูกค้า ทำเรื่องส่งเคลมสินค้าที่ใช้เวลารอของนานเป็นเดือน ส่งเครื่องแคลมถึง ตั้งแต่วันที่ 18/3/23 ครั้งแรกแจ้งว่ารอของ 7-10 วัน และได้ติดตามไปอีกครั้ง แจ้งว่าให้รออีก 21 วัน ซึงใช้เวลานานมาก แจ้งไปไม่เอาของแล้ว จะรับเงินคืน แจ้งมาอีกว่าของจะเข้าแล้ว แล้วต้องรอไปอีกเมื่อไร ร้านไม่มีใครรับผิดชอบอะไรเลยคะ ใครจะซื้อก็ซื้อนะคะ ขอผ่านคะ
# actual: 9
# predicted: 7.706289842912114
#
# comment: เปิดไม่ติด ชาร์จแบตไม่เข้าเลย ใครที่กำลังจะซื้อนาฬิกานี้บอกเลยผิดหวังแน่นอนค่ะ อย่าเสียเงินซื้อเลย คุณภาพแย่ขนาดนี้ไม่ต้องลงขายหรอกค่ะ
# actual: 9
# predicted: 7.7054872474370315
#
# comment: ได้รับสินค้าจากร้านนี้ไวมากครับ แอบตกใจมาก สั่งวันนี้ พรุ่งนี้ได้ของ งงเลยครับ แพ็คของดีมาก ขนส่งส่งไว เรื่องการใช้งาน บอกเลยดีเกินคาด ภาษาไทยต้องใช้แอพเสริมควบคู่ด้วย ดีจริงๆครับแนะนำเลย เล็กแต่มีประสิทธิภาพมาก แบตอึดด้วย ไฟสวยมาก อย่างแจ่ม
# actual: 9
# predicted: 7.691952285919078
#
# comment: ได้ของถูกใจ ราคาก็ถูก ส่งของไวมาก  ได้สมดังใจ ถือว่าประทับใจมากค่ะ ถูกใจมากๆๆเรยถือว่าคุ้มราคาค่ะ
# actual: 8
# predicted: 7.62391568815788
#
# comment: ซื้อช่วง 9.9 ราคาถูกลงมาก ส่งเร็ว ขนาดกำลังดีสำหรับอยู่หอพัก  หวังว่าจะใช้ได้นานเพราะตัวเครื่องเป็นพลาสติกดูบางๆ กลัวพังเร็ว ถ้าทนดีอาจมีซื้อยี่ห้อนี้อีกแน่นอน
# actual: 5
# predicted: 7.596377760044824
#
# comment: การจัดส่งค่อนข้างช้ามากๆค่ะ สั่งตั้งแต่วันที่1 ก็โอเคตรงที่มันติดวันหยุดรอได้ ขนส่งเข้ารับของตั้งแต่วันที่ 4 แต่ไม่เข้าใจว่าไปค้างทำไมที่Hub อยู่ตั้ง3 วัน ได้ของอีกวันที่ 7
# actual: 8
# predicted: 7.505539835299895
#
# comment: ดีงามมากค่ะ ราคาดี รูปร่างสวยงาม คุ้มค่า ได้เหรียญคืนอีก ชอบมาก บลูทูธ pair ง่าย ไม่มีปัญหาอะไร ส่งเร็ว ชอบมากถูกใจ
# actual: 7
# predicted: 7.415949027532046
#
# comment: ไม่แน่ใจว่าจะดีมั้ยจัดส่งช้ามากก ประมาณ 7 วันได้ ถ้ารีบบก็เปลี่ยนเจ้า แต่ถ้าไม่รีบก็รออ ซื้ือตอนแฟลชเซลล์ โอเคอยู่ เอาไปลดหย่อนภาษีได้ แต่รอใบกำกับนานนิดนึง จะได้หลังจากได้รับสินค้าแล้ว
# actual: 5
# predicted: 7.406466638127249
#
# comment: ใช้งานแก้ขัดได้ ใช้จริงจังไม่เหมาะร้านห่อมาโอเคอยู่ใส่บับเบิ้ลหลายชั้นทดลองใช้แล้ว ตอนชาร์จไฟเต็มไฟสีแดงจะดับ ใช้งานลำบากไม่เจอปุ่มแคปหน้าจอ หรือถ้าใครรู้ช่วยบอกที ที่ปัญหากวนใจมากคือเวลาพิมพ์โดยเฉพาะเขียนโค้ดถ้าเคอเซ่ออยู่ตรงไหนตัวพิมพ์จะย้ายไปตามทำให้พิมพ์ผิดถูกบ่อยไป และถ้าพิมพ์เร็วไม่ได้คีย์บอร์ดตามไม่ทันน้ำหนักเบาตัวอักษรไม่ชัด
# actual: 8
# predicted: 7.405838861757076
#
# comment: เวลาใส่ไอแพดแล้ว ยังมีบางจุดที่ไม่เข้าพอดี และเวลาตั้งเอียงๆ จะไม่ค่อยอยู่เท่าไหร่ เวลาเขียนน่าจะต้องวางราบไปกับพื้นเลย แต่โดยรวมคือดีนะ คุ้มราคาเลย
# actual: 9
# predicted: 7.398321481806696
#
# comment: สินค้าไม่มีตราปั๊ม MI
# actual: 2
# predicted: 7.375806895698783
#
# comment: ของแท้100%รับประกัน3ปี  ได้รับสินค้าแล้วค่ะ คุณภาพของสินค้าดีมาก ความรวดเร็วในการจัดส่งเร็วมาก การให้บริการจากร้านค้าดีมาก 👍🏻👍🏻👍🏻 สวยมากกกกกกกกก เสียงดี  ได้มาราคาถูกมาก ถูกกว่าร้านอื่นๆตอนลดราคาอีกด้วย คุ้มเกินคุ้ม ร้านค้าเป็นร้านที่เชื่อถือได้❤️❤️❤️
# actual: 8
# predicted: 7.3282217983322235
#
# comment: สินค้าจัดส่งเร็วค่ะ ทุกอย่างอยู่ในสภาพดี เชื่อมต่อผ่านแอพ fitpro นาฬิกาจะเปลี่ยนอัตโนมัติเมื่อเชื่อมกับแอพ ตั้งจากเครื่องไม่ได้ แจ้งเตือน การโทร  และข้อความได้ ถ้าใส่ตลอดเวลา แบตอยู่ได้ประมาณ หนึ่งวัน ราคานี้ทำได้ขนาดนี้ ถือว่าคุ้มมากๆ
# actual: 9
# predicted: 7.30984922982477
#
# comment: ได้รับสินค้าเมื่อวาน สินค้าตรงปกหรือป่าว จำไม่ได้ รู้แค่ว่า ส่งเร็วมาก ภายใน 1-2 วันได้รับสินค้าละได้รับสินค้าเมื่อวาน วันนี้ได้ลองใช้ละ ไม่ค่อยประทับใจในบางครั้ง ทิ้งไว้สักพัก ต้องมาไล่หาลูกศรของเม้าท์ใหม่ตลอด ขัดใจอยู่ ยังไม่ได้ลองแบบเสียบสายดู ถ้ายังงัยจะมาเพิ่มรีวิวให้นะ ขอทดลองใชเอีกสัก 2-3 วันดูก่อน
# actual: 4
# predicted: 7.307251972115572
#
# comment: ได้รับสินค้า เรียบร้อยแล้วค่ะ ลำโพง รุปทรงน่ารักดี เล็กกะทัดรัด สีสวย สดใสดีค่ะ การจัดส่งใช้ได้ค่ะ แต่เสียงลำโพงจะออกแหลมๆ หน่อย แต่ก็ฟังได้ค่ะ
# actual: 8
# predicted: 7.286990630721892
#
# comment: ได้ของมาวันที่13 วันนี้สั่นค้างแล้วก็ดับไปเลย เปิดไม่ติดอีกเลย ลองชาร์จแล้วก็ไม่มีการตอบสนอง
# actual: 8
# predicted: 7.220380099803648
#
# comment: ได้รับสินค้าแล้วครับ ใช้เวลาอัพเดทประมาณ 15 นาที
# actual: 3
# predicted: 7.2163340577037856
#
# comment: สายชาร์จ ใช้งานไม่ได้ค่ะ แต่ขี้เกียจคืนสินค้า  มันเสียเวลา ถามว่าเสียความรู้สึกไหม ก็นิดหน่อย ทางร้านจัดส่งรวดเร็วดี ไว้อุดหนุนใหม่แล้วกันคะ
# actual: 6
# predicted: 7.2033845898704545
#
# comment: จัดส่งรวดเร็วมากกก  แพ็คมาอย่างดีมากๆ  สินค้าน่าจะเป็นสินค้าเทียบ ใส่เครื่องฟอกอากาศได้พอดี ต้องรอใช้ซักระยะถึงจะรู้ว่าดีมั้ย
# actual: 7
# predicted: 7.197289610324715
#
# comment: คียร์บอดสีสวย ดูแข็งแรงมขนาดกระทัดรัด ร้านค้าแพคของมาดี จัดส่งรวดเร็ว สีที่เลือกไว้หมด แต่มีการโทรถามก่อน แนะนำค่ะ
# actual: 9
# predicted: 7.19618276563536
#
# comment: แนะนำครับ ส่งไว ราคาไม่แพง คุณภาพการบรรจุ สินค้า เยี่ยมมาก ส่วนการใช้งานเดียวว่ากันครับ
# actual: 4
# predicted: 7.111545919178276
#
# comment: ไม่สามารถเชื่อม fitpro ได้ เนื่องจากแอพถูกยกเลิกใช้ไปแล้ว อย่าซื้อ
# actual: 8
# predicted: 7.106309640070689
#
# comment: ได้รับสินค้าถูกต้องครบถ้วนตามที่สั่ง ลองทุกโหลดแล้วใช้งานได้ปกติดี ทั้ง bluetooth และ SD Card คุณภาพเสียงตามราคา เบาเล็กพกพาสะดวก
# actual: 8
# predicted: 7.105704353248472
#
# comment: สั่งเซ็ทเขียวแต่ไหงได้ลูกครึ่ง กล่องเมาส์มีบุบมาหน่อย คนส่งอาจไม่ได้เช็ค แต่เราใช้งานได้ไม่ติดไรเลยไม่อยากคืนของเสียเวลา แต่ทางร้านควรเช็คกว่านี้ ตัวคีย์บอร์ดเล็กๆบางๆ ต่อกับบลูทูธพกไปไหนสะดวก เมาส์ต้องต่อกับ usb 2.4 โดยรวมใช้แล้วสะดวกดี ติดแค่เรื่องสีแค่นั้น
# actual: 8
# predicted: 7.0985603428362225
#
# comment: สินค้ามีคุณภาพดีสินค้าใช้งานได้ดี แต่การบริการ และการประชาสัมพันธ์มีปัญหา ไม่ระบุรายละเอียดให้ชัดเจน ผิดหวังมาก
# actual: 6
# predicted: 7.098332642367163
#
# comment: จัดส่งรวดเร็ว สวยงามมินิมอล ราคาไม่แพงค่ะ เสียงดีระดับหนึ่งนะคะ แต่แพคมาไม่ค่อยดีห่อบับเบิ้ลมา 1 ชั้น กล่องบุบ ทำให้ตัวเครื่องบุบไปมุมหนึ่ง น่าเสียดาย 😭
# actual: 8
# predicted: 7.094911923413565
#
# comment: ได้สีไม่ตรงที่สั่ง ร้านไม่รับผิดชอบ ไม่ขอโทษ ไม่อ่าน ไม่ตอบแชทใดๆทั้งสิ้น แย่มาก เสียความรู้สึก สายแถมไม่มี
# actual: 9
# predicted: 7.092596733567945
#
# comment: ส่งผิดสี  แต่ สีนี้ ก็สวย เอาสีนี้ก็ได้คะ
# actual: 3
# predicted: 7.0513349885172625
#
# comment: เนื่องจากสั่งสินค้าไปให้ลูกสาวใช้ ทำให้ไม่เห็นสินค้าด้วยตัวเอง สินค้าราคาไม่แพง ค่าขนส่งถูก จัดส่งไว ... ถ้าใช้ดีมีโอกาสจะสั่งซื้อสินค้าอีกครั้ง
# actual: 1
# predicted: 7.012725679131896
#
# comment: สินค้าจีน ร้านค้าเอามาตีแบรนด์ วัสดุ พลาสติก ยังเกรดกลางๆ ตอนพัง เครื่องละลาย กลิ่นพลาสติกคือเคมีมากค่ะ แต่ร้านค้ามีเซอร์วิส บริการและการดูแลหลังการขาย รับซ่อม
# actual: 7
# predicted: 7.00688143190102
#
# comment: อันนี้เพื่อนฝากซื้อค่าาา เพื่อนเห็นเราใช้แล้วอยากได้ตาม เรายืนยันเลยค่ะว่าดีจริง แบตอึดเกินราคาไปมาก ส่วนตัวไม่ใช่คนใส่หูฟังตลอด เก็บเสียงจากภายนอกได้ดีมาก คุณภาพเกินราคาเลย เห็นยอดขายเยอะมากๆ
# actual: 6
# predicted: 6.995210469044442
#
# comment: คุณภาพสินค้าสมราคาค่ะ ความคุ้มค่าไม่คุ้มค่าค่ะ ทางร้านแพ็คสินค้ามาพอใช้ค่ะ การขนส่งสินค้าดีมากค่ะ 😁😁😁😁😁😁😁😁😁😁😁😁 ใช้ได้วันเดียว ไม่กี่ชั่วโมง แบตฯก็หมดค่ะ ชาร์ตไม่เข้า เปิดไม่ติดอีกเลย จะทำเรื่องคืนก็คิดว่ายุ่งยาก
# actual: 9
# predicted: 6.975473767457341
#
# comment: แย่มาก สินค้าชำรุด
# actual: 5
# predicted: 6.974835364468762
#
# comment: วัสดุคือบ้งมากกกกกกกก ภาพไม่ตรงปกติ จริงๆ แล้วอย่าเห็นแก่ของราคาถูกเลยค่ะ สินค้าตัวนี้คือแบบบ ใช้ได้แปปปเดี่ยวคือพัง 555555 ว่าจะทิ้งแล้ว ไม่ถูกใจค่ะ แนะนให้ซื้อราคา 299 ขึ้นไป เพราะปกติเคยใช้ราคาสูงกว่านี้คุณภาพคือดีมาก
# actual: 8
# predicted: 6.962202678429313
#
# comment: สั่งซื้อเป็นอันที่ 2 แล้วค่ะ ได้รับสินค้าตรงตามที่สั่งสินค้ามีความเหมาะสมกับราคา สวยงามแข็งแรงเล็กๆน่ารักใส่กระเป๋ากางเกงสบายเลยค่ะ เชื่อมต่อง่าย
# actual: 7
# predicted: 6.899770400056552
#
# comment: คุณภาพดี
# actual: 1
# predicted: 6.895105811043413
#
# comment: ได้รับสินค้าแล้ว ส่งตรงตามที่สั่ง เล็กกระทัดรัด เสียงพอใช้ แต่เสียงเบสไม่ค่อยทุ้มมีแต่เสียงแหลม
# actual: 8
# predicted: 6.893519433896858
#
# comment: ได้รับสินค้ารวดเร็ว ได้รับสินค้าถูกต้อง สินค้ามีการปกป้องที่ดี สินค้าดี มีคุณภาพ สินค้าราคาประหยัด สวยงามดี
# actual: 2
# predicted: 6.89064046480483
#
# comment: ส่งผิดสี ไม่มีกันกระแทก
# actual: 4
# predicted: 6.884049378847193
#
# comment: สินค้าดูดี ราคาไม่แพง การแพ็คสินค้า แพ็คมาดี การจัดส่งก็ไว แต่ เราพลาดเองไม่ได้อ่านให้ดีก่อนว่าเป็นของเทียบ ไม่ใช่ของ mi แท้ ถูกกว่าไม่เท่าไหร่เอง
# actual: 7
# predicted: 6.87426521730277
#
# comment: รบกวนมาตอบคำถามด้วยค่ะ เชื่อมต่อบลูทูธไม่ได้ ถามเป็นวันไม่ได้คำตอบ
# actual: 4
# predicted: 6.850642880291977
#
# comment: ใส่ซองพลาสติกมา แกะออกดูใจหายแว๊บบบบบบ ไมเม้าท์มันอ้างี้อะ😱 ดีที่บีบคืนแล้วใช้ได้ปกติ ส่วนคีบอร์ดเชื่อมต่อง่ายใช้ได้ปกติแต่ติดปัญหาพิมพ์ภาษาไทยไม่ได้ต้องไปโหลดแอปเสริม ซึ่งทักไปถาม admin ตอบกลับเร็วดีและส่งลิ้งค์ 9420 thai keyboard มาให้แต่ปรากฏว่า nokia t20 android 11ไม่รองรับแอพนี้ กว่าจะหา app ภาษาไทยที่ใช้ได้เล่นเอาเหนื่อย 😅😅😅
# actual: 8
# predicted: 6.812188101008259
#
# comment: ตะมุตะมิน่ารัก  เสียงแจ่มดีค่ะ  ชอบมาก  ราคาไม่แพงด้วย
# actual: 6
# predicted: 6.811750303662222
#
# comment: ตกหลายรอบมากค่ะล่าสุด แต่น้องแอบทนอยุ่ค่ะ เสียงดังพอใช้ แต่แบต นานมากค่ะกว่าจะหมด  แต่ถ้าใช้ดูหนังนานๆสูงสุดได้ 3 ชั่วโมงแบบต่อเนื่องญิ้ง
# actual: 9
# predicted: 6.802986258300445
#
# comment: goodจัดส่งรวดเร็วทันใจ สินค้าตรงปก คุณภาพเกินราคา ราคาไม่แพงมาก  ไม่ผิดหวัง สมราคา ใช้งานได้จริง แนะนำซื้อเลย ของแท้แน่นอน ซื้อเลย
# actual: 5
# predicted: 6.801425795805903
#
# comment: คุณภาพเสียงปลานกลาง เบสไม่ค่อยหนักเท่าไหร่ สมกับราคา ถ้าเน้น เบสหนักๆต้อง JBL มาเชล สำหรับ aj เสียงกลางๆ ราคากลางๆ พอใช้ได้
# actual: 7
# predicted: 6.782595277124504
#
# comment: สภาพการส่งคืบบ นึกว่าจะห่อกันกระแทกมาให้บ้าง กล่องคือขาอบุป บู้บี้มาเรย ชื้อค่ะ ไม่ได้ขอฟรี  แค่บับเบิ้ลห่อไม่ได้ งงใจ
# actual: 5
# predicted: 6.693939998965166
#
# comment: แย่มากค่ะสั้งพร้อมเคสแต่ไห้เคสมาผิดรุ่น
# actual: 3
# predicted: 6.68889085422542
#
# comment: แย่มากค่ะ เสียงดังยังกะแมงหวี่ คือแทบจะเงี่ยหูฟังเลย เสียดายตังมากค่ะ ไม่น่าสั่งมาจริงๆๆรูปทรงสวยใหญ่ แต่คุณภาพแย่มาก ไม่แนะนำค่ะใครที่คิดจะซื้อ
# actual: 9
# predicted: 6.686467185304244
#
# comment: ได้รับของไม่ตรงตามที่สั่ง สั่งหูแมวได้แบบปกติมาค่ะ ควรตรวจสอบสินค้าให้ดีก่อนส่งนะคะ
# actual: 6
# predicted: 6.679379778448076
#
# comment: ไม่สามารถใช้งานได้ ส่งสินค้าคืนกลับไปพร้อมโน๊ต รอสินค้ากลับคืนมาให้ใหม่อยู่ค่ะ รอนานๆๆๆๆๆๆๆๆๆๆๆๆๆ ติดต่อกลับไปทางแอดมินบอกให้รอคิว 2 อาทิตย์แล้วยังไม่ได้ของคืนกลับมาเลยค่ะ รู้สึกแย่มาก รอสินค้านานนนนนนนนนนนนนนนนนนนนนนน
# actual: 9
# predicted: 6.630371695330142
#
# comment: สินค้าคุณภาพพอใช้ได้อาจจะมีสัญญาณหลุดๆบ้างเป็นบางครั้ง แต่ก็ถือว่าพอรับได้ ขนส่งไวดี สั่ง2วันส่งถึง
# actual: 4
# predicted: 6.618878185445185
#
# comment: ได้รับสินค้าถึงมือเรียบร้อย ส่งไวมากๆ เป็นคนชอบฟังเพลงเลยตัดสินใจซื้อ ประทับใจมากๆ แถมซองหนังใส่ตัวลำโพงมาด้วยดีมากๆ โดยรวมถือว่าประทับใจมากซื้อจากช็อปมั่นใจได้ของแท้ 👍👍👍
# actual: 9
# predicted: 6.618595324962699
#
# comment: สายชาร์จที่ให้มาใช้ไม่ได้ค่ะ ส่วนเรื่องเสียง ถือว่าดีเลย แต่หูฟังทั้งสองข้างเสียงไม่เท่ากันค่ะ หนึ่งข้างเสียงดัง หนึ่งข้างเสียงเบา ไมค์ใช้ได้ค่ะ
# actual: 8
# predicted: 6.616471312035787
#
# comment: ดีมากเมาส์ลื่น ไม่มีสะดุด เบา จับกระชับมือดี  ราคาถูกดี คุ้มค่า จะต้องดูว่าจะได้นานแค่ไหนครับ
# actual: 5
# predicted: 6.604643159996532
#
# comment: ของได้ครบ การจัดส่งไวพอสมควร แต่กล่องสินค้ายับและบุบมาก ไม่รู้จะมีปัญหากับสินค้าหรือเปล่า สกสดยดนกสดดดดเสเส
# actual: 3
# predicted: 6.6017275303251335
#
# comment: ถือว่าโอเคดี แต่ต้องกดเพิ่มเสียงเยอะหน่อยถึงได้ยินชัด ตัวหูฟังเล็กน่ารัก พกพาสะดวก ใส่แล้วไม่เจ็บหู ไม่หลุดง่าย
# actual: 6
# predicted: 6.601681776920401
#
# comment: ไม่เหมือนตัวเก่าที่ซื้อด้านล่างดูวัสดุเกรดคุณภาพดีกว่ามาก ตัวบนที่ซื้อใหม่ดูใส้กรอกแบบปกติและรูกว้างกว่ามาก วัสดุที่ใช้เกรเต่ำกว่า
# actual: 6
# predicted: 6.601039393660622
#
# comment: ขนาดเล็ก บางเบา พกพาไปไหนได้สะดวก แต่ก็แอบกลัวงอกลัวหักอยู่เหมือนกัน ตัววัสดุไม่ได้แข็งแรงมาก บิดแล้วงอได้ ลองใช้ดูแล้ว คีย์บอร์ดดีเลย์น้อยมาก ถือว่าดี ใช้ไปนานๆแบตเริ่มหมดไฟคีย์บอร์ดจะใช้ไม่ค่อยได้
# actual: 8
# predicted: 6.595451383601888
#
# comment: พอใช้
# actual: 1
# predicted: 6.585489262638874
#
# comment: สินค้าไม่ตรงปก  กดสั่งมีลายคิตตี้ แต่ได้ไม่มีลายมา ผิดหวังมาก
# actual: 8
# predicted: 6.579631529311571
#
# comment: อีกตัวเชื่อมต่อได้ปกติแต่อีกตัวค้นหาบลูทูธไม่เธอเลย ถามคนขายคนขายก็ไม่บอก
# actual: 6
# predicted: 6.575144398252509
#
# comment: สินค้าสวยดีสายที่แถมมาให้นิ่มดี  คุณภาพของสินค้าดี ความคุ้มค่าดี ความรวดเร็วในการจัดส่งดี การให้บริการร้านค้าดี การให้บริการบริษัทขนส่งดี
# actual: 8
# predicted: 6.549884611967564
#
# comment: พลังเสียงชัดเจน โอเคเลย
# actual: 4
# predicted: 6.51849382995889
#
# comment: ส่งสินค้าไว ได้ตามสีที่สั่ง ทดลองใช้แล้วใช้ได้ตามที่ function ที่ระบุ เหมาะสำหรับพกพาไปเที่ยวกับครอบครัวนอกสถานที่
# actual: 6
# predicted: 6.51174513303291
#
# comment: ใช้มาจะ1เดือนแล้ว ดีมาก แบตอึดแบตทนใช่ดีมากแบตอึดแบตทน ใช้มาเกือบจะ1เดือน เครื่องไม่มีปัญหา แต่ติดตรงที่line ไม่แจ้งเตือน
# actual: 8
# predicted: 6.508720080824866
#
# comment: ได้รับสินค้าแล้วการจัดส่งรวดเร็วดีนะ คุณภาพสินค้าโดยรวมพอรับได้ แต่ที่แย่มากคือสั่งสินค้าไป2ชิ้น แต่ส่งมาเพียงแค่ชิ้นเดียว การคืนเงินก็ช้า
# actual: 7
# predicted: 6.494120000134423
#
# comment: สินค้าตรงตามปกที่สั่ง ไม่แตกหักเสียหาย เปิดติด เชื่อมต่อง่าย ทั้งแฟลชไดร์ฟทั้งบลูทูธ  คุณภาพเสียงให้มา กลาง / แหลม ใส
# actual: 6
# predicted: 6.492457420310467
#
# comment: การจัดส่งไม่ห่อกล่องทับอีกที กล่องบุบ
# actual: 4
# predicted: 6.487698914602513
#
# comment: ส่งไว กว่าที่บอกไว้นะคะ แต่ไม่หุ้มกันกระแทกมาทำให้กล่องบุปขาดตามรูปดีที่สินค้าไม่เสียหายซื้อตอนแฟลชเซลล์ ได้ราคาดีแถมได้ส่วนลด คุ้มค่ามากคะ โดยรวมชอบคะ
# actual: 9
# predicted: 6.420703979814332
#
# comment: สั่งสีน้ำเงิน ได้สีเทามา เห้ออออ
# actual: 4
# predicted: 6.409952203236562
#
# comment: กล่องชำรุดนิดหน่อย สิ้นค้าดูโอเคร แผ่นกรองอากาศด้านหลังมีเม็ดคาร์บอนตาข่ายเป็นรู ถือว่าใช้ได้ในระดับนี้...🥳
# actual: 4
# predicted: 6.403337831450563
#
# comment: ได้รับ นาฬิกา แล้ว ห่อมาไม่ดีเลย ดีนะกล่องไม่ยับ หรือบุบ ของแพงๆ น่าจะห่อมาดีๆหน่อยนะ ส่วนนาฬิกาต้องขอลองก่อน เดี่ยวมาบอก
# actual: 6
# predicted: 6.397501835091634
#
# comment: จัดส่งล่าช้า มากกกก แย่ 5-6 วันได้ของ
# actual: 7
# predicted: 6.393250910513353
#
# comment: ดีมาก คุ้มราคา มีคู่มือภาษาอังกฤษให้ด้วย เชื่อมต่อบูลทูธได้ง่าย hotkey ต่างๆ ใช้งานได้ตามคู่มือ รวมถึงทัชแพดด้วย
# actual: 8
# predicted: 6.3901207456434586
#
# comment: ก่อนจะสั่งซื้อได้ดูขนาดเครื่องแล้วเป็นรุ่นใหญ่เท่ากับที่เคยซื้อ แต่พอได้รับสินค้ามาไม่ตรงปก ขนาดเล็กกว่าที่ลงรายละเอียดไว้ เล็กเท่ารุ่นเล็กเลย ไส้กรองก็เล็ก ร้านค้าควรแก้ขนาดให้เท่ากับที่ขายจริง
# actual: 7
# predicted: 6.27418834813772
#
# comment: ของมีตำนิ มีลอย  การทำงานการใช้งานยังไม่รุ้ ต้อง ลองดูก่อน ครับ  ขอบคุณครับ
# actual: 4
# predicted: 6.260006253885651
#
# comment: บริษัทขนส่งช้ามาก ค้างอยู่ตั้งนาน เกือบอาทิตย์
# actual: 5
# predicted: 6.258560863945184
#
# comment: นาฬิกาสวย วัดการเต้นของหัวใจได้ ฟังก์ชันกีฬาต่างๆเยอะมาก คุ้มค่ากับราคา จากที่ใช้มา 3 วันยังไม่เกิดปัญหาการใช้งานใดๆ
# actual: 8
# predicted: 6.221600467560383
#
# comment: ทางร้านส่งสีให้ไม่ตรงกับที่สั่งเลยค่า สั่งสีดำได้ สีแดงน้ำเงิน ละสั่งอีกรุ่นแต่ส่งรุ่นนี้มาผิดสีไปหมด อยากให้เช็คเรื่องนี้จริงๆนะคะ +เชื่อมบลูธูทไม่ได้ 1 ตัว
# actual: 8
# predicted: 6.1865591872464645
#
# comment: เมาส์เชื่อมต่อไม่ได้ ลองทุกวิธีทางแล้วค่ะ ค้นหาตัวบลูทูธเม้าส์ไม่เจอเลย
# actual: 5
# predicted: 6.1679577797163825
#
# comment: การขนส่งนานนิดหน่อยเพราะส่งมาจากจีน คุณภาพเสียงก็ตามราคาพอใช้ได้ คุยโทรศัพท์ได้ไม่ถึงกับชัดมาก
# actual: 5
# predicted: 6.159877118451619
#
# comment: ดูมานานลองสั่งมาให้ลูก ส่งเร็วดี ราคาไม่แพง หัดตรงที่แพ็คของมาเหมือนไม่ได้แพ๊คแต่ของไม่เสียหายอะไร คุ้มอยู่ ราคาไม่แพง ใช้ง่าย เครื่องค่อนข้างเงียบไม่ดังมาก
# actual: 8
# predicted: 6.129762832752784
#
# comment: อันแรกมันพังตรงปุ่มหยุดและที่เสียบมันยุบเข้าไปด้านในอ่ะคือผิดหวังมากแต่ก็ยังดีที่อันที่2สมบูรณ์หมดแต่ถ้าแนะนำสั่งร้านอื่นดีกว่า ทุกอย่างดีหมดอ่ะยกเว้นปุ่มกับที่เสียบมีแหละ
# actual: 8
# predicted: 6.105596593999109
#
# comment: ให้​4​ ดาว​ ส่งไว​ พนักงานสร้างเงื่อนไขไม่ชอบ​ หูฟังรูปแบบสวยงาม​ แต่ชอบสีเงินๆ​ และเงาหลากสีไม่รู้​เค้าเรียกอะไรลองเสียบฟังแล้วเสียงไม่ดี​สำหรับความคิดเรานะ​ คนอิ่นอาจ​มอง​ แล้วลองฟังเห็นว่า​ดีก็ได้​ ก็พึ่งเคยใด้ใช้ครั้งแรก​ พอฟังได้​ ระบบเสียงก็สมราคาแร่ะ😅😅
# actual: 8
# predicted: 6.099725390938714
#
# comment: พอใช้ขาล็อกฝาหักข้างนึงปิดไม่ยู่ไม่มีผลต่อการใช้งานต้องใช้เทฟกาวปิดร้านน่าจะเช็คให้ลูกค้าบ้างกะดีส่งไวใช้ได้
# actual: 7
# predicted: 6.096052509312373
#
# comment: ส่งช้ากว่าที่คิดค่ะ 3-4 วันได้รับของ ปกติเคยเจอแต่ร้าน official ส่งเร็ว (ยกเว้นข้าวสาร) ยังไม่ได้ลองใช้ว่าดีมั้ย
# actual: 4
# predicted: 6.095522028521539
#
# comment: สินค้าดีเเต่เเพ็คเราว่าใส่กล่องเพ็คมาดีกว่า
# actual: 5
# predicted: 6.091423528380493
#
# comment: สกสดสอาอมมออมะสพนดนาาดสกมมดอากมดมอาอมมดดมดสดสดสดสดสสเสดพสดสดสดสสเดสดสสเสเดสวกงดววดดสดสสดเสสเสเสเสดสเส
# actual: 0
# predicted: 6.089803586623158
#
# comment: ไม่มีตัวปล่อยประจุไอออนลบมาให้ มีแต่ฟังชั่น
# actual: 2
# predicted: 6.02264315462243
#
# comment: ได้มาจัดส่งเร็ว  แต่สินค้าเปิดไม่ติด
# actual: 2
# predicted: 5.99803249702215
#
# comment: จัดส่งถือว่าเร็วครับ สินค้าคุณภาพพอดีครับ เสียงดี เบสดี รวมๆถือว่าโอเคร มาตำจ้าาาาาาาาาาาาาาาาทททท
# actual: 6
# predicted: 5.99747508504525
#
# comment: แย่มากๆกดอะไรแทบไม่ได้หลายๆอย่าง
# actual: 7
# predicted: 5.992259151251689
#
# comment: ชอบดีขนานกำลังดี
# actual: 4
# predicted: 5.978384669644895
#
# comment: เชื่อมต่อง่ายดี ใช้งานได้ดีมาก วัสดุอุปกรณ์มีความแข็งแรงดีมาก รูปทรงเท่สวยหรู เสียงดีเกินคาดเบสมาเป็นลูกถูกใจ
# actual: 4
# predicted: 5.94966404526691
#
# comment: -ปานกลาง ใช้ได้
# actual: 1
# predicted: 5.919027105023145
#
# comment: ตอนแรกเปิดติดค่ะ แล้วก็เปิดไม่ติดแล้ว เศร้า ตอนแรกเปิดติดค่ะ แล้วก็เปิดไม่ติดแล้ว เศร้า ตอนแรกเปิดติดค่ะ แล้วก็เปิดไม่ติดแล้ว เศร้า ตอนแรกเปิดติดค่ะ แล้วก็เปิดไม่ติดแล้ว เศร้า
# actual: 5
# predicted: 5.917500071584652
#
# comment: ที่วางโทรศัพท์บางเกนไป ใส่โทรศัพท์ไม่ได้
# actual: 0
# predicted: 5.917344626544981
#
# comment: แตกนิดหน่อยแต่ไม่ได้กระทบการใช้งานรับได้ค่ะ
# actual: 4
# predicted: 5.913552719128205
#
# comment: แพ็คมาดีค่ะ ส่งช้านิดนึงแต่ช่วงนี้สภาพอากาศไม่ดีเข้าใจได้ แถมสติ้กเก้อมาด้วยน่ารักค่า
# actual: 7
# predicted: 5.909247443206833
#
# comment: สินค้าส่งจากประเทศจีน ค่าส่งไม่แพง รับส่งบูลทูทเร็วดี แต่แพร์ได้เพียงเครื่องเดียว พบายามแพร์กับมือถือสองเครื่อง ทำไม่ได้สักที เลยต้องใช้เครื่องเดียว แถมยังหาวิธีปิดเครื่องไม่ได้ ต้องชาร์ททุกวัน ราคาปานกลาง ไม่แพงและไม่ถูก แต่สีสวย ทั้งหูฟังและกล่อง
# actual: 9
# predicted: 5.897482552691036
#
# comment: สินค้าน่ารัก ขนาดกะทัดรัดดีค่ะ แต่ส่ามีตำหนิรอบดำตรงที่เสียบสายUSB นิดหน่อย ส่วนการใช้งานยังไม่ได้ทดลองใช้เลย
# actual: 4
# predicted: 5.892936048811593
#
# comment: พอใช้ตัวล็อกฝาเปิดแตกหัก หลวม
# actual: 3
# predicted: 5.888259082416537
#
# comment: สั่งสีชมพูมีหู แต่ได้แบบธรรมดามา
# actual: 4
# predicted: 5.883140219594169
#
# comment: ฟิลเตอร์เครื่องกรองกากาศsharpพร้อมชั้นคาร์บอนสามารถใช้แทนของแบรนด์ได้  การจัดส่งรวดเร็วดี
# actual: 3
# predicted: 5.876608457808292
#
# comment: ได้อยู่พอใช้
# actual: 2
# predicted: 5.874040319580048
#
# comment: ดีค่ะ ใช้งานได้จริงจัดส่งไว  ตรงปก มีอุปกรณ์แถมมาอย่างดี ❤️
# actual: 7
# predicted: 5.867799783216299
#
# comment: โอเคเลยค่ะ เหมาะสมตามราคา ปุ่มนิ้มมาก แม่แหล็กปิดฝาเบาบางไปหน่อย แต่โอเคค่ะ จัดส่งไว กล่องบู้บี้และฉีกขาด แต่สินค้าสภาพโอเคค่ะ
# actual: 8
# predicted: 5.80947948463096
#
# comment: ใช้ได้แค่วันเดียวก็พังแล้ว เสียงเพลงไม่ออก เพิ่มเสียงสุดแล้ว
# actual: 5
# predicted: 5.8077514804723
#
# comment: หน้าปัดที่มีให้เลิือกน้อยไปหน่อยฟีเจอร์กับทัชสกรีนธรรมดาหน่วงๆนิดหน่อยแต่โดยรวมเทียบกับราคาคือไม่แย่เลย
# actual: 7
# predicted: 5.778407381089447
#
# comment: สินค้าส่งเร็ว เสียงดังฟังชัดคุณภาพสมราคา 👍👍👍👍👍
# actual: 6
# predicted: 5.751043099945986
#
# comment: ขอบคุณผู้ขายและผู้ขับขี่งานของ shopee สําหรับงานที่จะทําให้กับ shopee
# actual: 0
# predicted: 5.722790651210504
#
# comment: ส่งมาดีแพ็คมาดีแต่ผิดรุ่นเสียเงินทิ้งบอกใส่ได้กับทุกรุ่น ความจริงใส่ไม่ได้เลยแม้แต่รุ่นเดียว
# actual: 9
# predicted: 5.715254744203504
#
# comment: ใช้งานดี​ สบายจมูกขึ้นเยอะเลย​ ติดที่ส่งช้า​ ตอนแรกจะให้เรากดขยายเวลาส่งด้วย​เราอ่านไม่ตอบ​ สักพักขึ้นว่าพัสดุ​กำลังจัดส่งแล้ว​ เอองงเหมือนกัน
# actual: 5
# predicted: 5.7134660848837475
#
# comment: เสียงดูวิโอก็ดีอยู่เสียงดีเลย์ไม่ตรงตอนโทรเสียงพูดเบามากเเละตอนเชื่อมต่อมันไม่ได้ขึ้นว่า i13เเต่ขึ้น i12 เเต่ส่งเร็วอยู่ให้ฟังเพลงได้อยู่เเต่เล่นเกมคุยกับเพื่อนนี้เเย่มาก
# actual: 9
# predicted: 5.711508771829757
#
# comment: สิ้นค้าแตก แต่ยังเปิดเครื่องใช้งานได้
# actual: 3
# predicted: 5.710018920594585
#
# comment: ค่อนข้างช้าค่ะ แต่น่าจะดีมานเยอะช่วงนี้ ภาพรวมสินค้าใช้งานครั้งแรกได้ไม่มีปัญหาอะไร
# actual: 5
# predicted: 5.694072570614324
#
# comment: สั่งสีน้ำเงินได้สีเขียวแถมเปิดไม่ติดด้วย 😥😥
# actual: 6
# predicted: 5.691837386870619
#
# comment: ทักทางร้านไม่ตอบ ในรูปตัวอย่างมีสายแจ๊ส ของมาถึงไม่มีไม่มีการบริการดูแล
# actual: 5
# predicted: 5.683020431364525
#
# comment: ตัดสินใจอยู่นานเลยครับ พอได้รับของก็ประทับใจดีครับ ราคาดี เสียงดีครับ
# actual: 7
# predicted: 5.672517045175284
#
# comment: ดีค่ะ สมกับราคา แถมสามารถใช้คุยโทรศัพท์ได้ค่ะ รวมๆแล้วคือดีหมดค่ะ แพ็คดีค่ะ รูปแบบลำโพงดังเสียงชัดค่ะ
# actual: 9
# predicted: 5.598881278157617
#
# comment: ส่งไวงานดี แต่งงว่าทำไมตัวกรองมันไม่ซิวพลาสติกมาเหมือนในคู่มือ
# actual: 5
# predicted: 5.593676485570891
#
# comment: สั้งสีแดงแต่ได้สีเขียว...แต่ไม่เป็นไรรับได้
# actual: 4
# predicted: 5.5820776732437
#
# comment: สั่งสีดำ ได้ทหาร ก่อนส่งเช็คของหน่อยก็ดีค่ะ
# actual: 5
# predicted: 5.552560907179982
#
# comment: การจัดส่งไม่ดีเท่าไหร่ สินค้าถึงไม่ตรงกับวันที่ตกลงไว้ แต่สินค้าดูสวยงามมากๆ
# actual: 5
# predicted: 5.506370961606997
#
# comment: ไอน้ำออกเบามากๆๆๆๆๆ  มากๆๆ
# actual: 3
# predicted: 5.505246896639153
#
# comment: มีคราบสีดำเปรอะ เช็ดไม่ออก ดูเก่ามาก
# actual: 5
# predicted: 5.503884882073225
#
# comment: นาฬิกาข้อมืออัจฉริยะราคาประหยัด ตัวสายทำจากซิลิโคน ตัวเรือนชาร์จได้ มีหัวชาร์จแถมมาให้ด้วย การจัดส่งอาจจะค่อนข้างช้าพอสมควรเพราะส่งจากต่างประเทศ ทางร้านห่อพัสดุกันกระแทกมาอย่างดี
# actual: 7
# predicted: 5.502304687629488
#
# comment: ไม่มีสติ๊กเกอร์แถมมาให้ค่ะ นึกว่าจะมีให้มาเลยแอบเสียใจนิดๆ
# actual: 3
# predicted: 5.491475265832927
#
# comment: ส่งช้าไป ติดต่อยาก เหมือนคุยกับบอท
# actual: 5
# predicted: 5.491334025856147
#
# comment: หูฟังเร่งเสียงเองตลอด
# actual: 2
# predicted: 5.483382928567965
#
# comment: สินค้ารอนานจากจีน
# actual: 3
# predicted: 5.458017154679875
#
# comment: กะทัดรัด​ ใช้งานง่าย ชอบ​มาก​เลย​คร่า
# actual: 5
# predicted: 5.440550762368513
#
# comment: เสียงพูด อีกฟังได้ยินไม่ชัด
# actual: 3
# predicted: 5.439212895390421
#
# comment: ฉันไม่ได้รับสิ่งที่ฉันขอ พวกเขาไม่ส่งสิ่งที่พวกเขาแสดง
# actual: 3
# predicted: 5.35217754775227
#
# comment: ใช้ดีมากสะดวกใช้ดีมากๆเลย
# actual: 3
# predicted: 5.344569164706634
#
# comment: สั่งสีดำ ได้สีครีม 🙄
# actual: 4
# predicted: 5.343246956860253
#
# comment: โดยรวมตรงปก+กับทางร้านแถมที่รองเม้าส์ให้ด้วยเบาไม่หนักถือว่าโอเคแต่ไฟไม่ติด
# actual: 4
# predicted: 5.290013203103395
#
# comment: ร้านได้ของคืนและคืนเงินให้ค่ะ​ ถือว่ารับผิดชอบดีค่ะ​ ขอบคุณ​ค่ะ
# actual: 6
# predicted: 5.289437190799427
#
# comment: ได้ของเร็วแต่เสียงติดๆดับๆตลอดเลยไม่รู้ว่าเป็นที่อะไรลองทดลองใช้ช้าๆก็ยังเป็นค่อนข้าง​ผิดหวังนิดหน่อยค่ะ
# actual: 5
# predicted: 5.210880254179376
#
# comment: เคสแน่นไปนิดนึง ติดเนื้อของตัวชาร์จเลย เสียงไม่ค่อยดังเท่าไหร่แต่ก็ถือว่าดีมากอยู่นะ แล้วก็มันใหญ่มากหรือหูเราเล็กไปก็ไม่รู้ มันใส่แล้วมันชอบหลุด แล้วก็มือไปโดนนิดเดียวมันก็จะหยุดเล่นวิดีโอแต่ก็เข้าใจได้เพราะเป็นระบบแบบสัมผัส ￼
# actual: 8
# predicted: 5.207768167966888
#
# comment: คุณภาพสินค้าดี แต่จัดส่งช้าค่ะ
# actual: 5
# predicted: 5.1954564800421785
#
# comment: เสียงไม่ค่อยเท่าไร สมราคา
# actual: 4
# predicted: 5.178408241049596
#
# comment: ผลิตภัณฑ์ปกติมาก
# actual: 2
# predicted: 5.163521824133951
#
# comment: สินค้าน่ารักสมราคาดีค่ะจัดส่งไวมากก
# actual: 7
# predicted: 5.1078193194705035
#
# comment: ค่าเลขกรองฝุ่นอาจไม่ตรงกับเครื่องวัดฝุ่นค่ะเลยไม่แน่ใจประสิทธิภาพการกรอง
# actual: 5
# predicted: 5.103800978113412
#
# comment: พอใช้ได้คะ ไม่เก็บเสียรอบข้างเลย
# actual: 3
# predicted: 5.09344475305967
#
# comment: สภาพกล่องลำโพงเละเทะมากตั้งเเต่เเกะ ต้องชาร์จลำโพงตลอดเวลาถึงใช้ได้ บลูทูธหลุดบ่อย
# actual: 8
# predicted: 5.069820280986392
#
# comment: เสียงดี สินค้าตรงปก กล่องสวยมาก
# actual: 3
# predicted: 5.0459789077891335
#
# comment: สินค้าชำรุด
# actual: 3
# predicted: 5.023690008973789
#
# comment: เพื่อนแนะนำให้ใช้เพื่อถนอมตํว​ filter.ส่วนคุณสมบัติของแต่ล่ะร้านค้าต่างกันมั้ยอันนี้ไม่ทราบนะครับ​ ใช้ได้กรองได้ในราคาที่ไม่สูงเกินไปก็​ ok.แล้วครับ​ ขอให้ขายดีครับ
# actual: 4
# predicted: 5.019479647250368
#
# comment: ได้รับลำโพงตรงตามที่โฆษณา ได้รับสีตรงตามที่เลือก รูปทรงน่ารัก เสียงพอใช้  ฟังก์ชั่นใช้งานง่าย ตรงมุมมีบุบไปบ้างจากการขนส่ง แต่ไม่มาก อยากให้ห่อหุ้มกันกระแทกให้ดีกว่านี้
# actual: 8
# predicted: 5.014759927892645
#
# comment: ซื้อมาแล้วฟังได้ข้างเดียวผมอยากฟัง2ข้างอะครับ
# actual: 5
# predicted: 4.986652541539143
#
# comment: สั่งสีขาวได้สีดำ ขอบคุณค่ะ
# actual: 5
# predicted: 4.984345953381762
#
# comment: ใช้งานได้สองอาทิตย์เปิดไม่ติดแล้วเสียใจ
# actual: 7
# predicted: 4.889597101160702
#
# comment: ใช้ทำไรก้ไม่ได้เลยเวลาก็ตั้งไมไ่ด้เชื่อมก็ไม่ได้ เป็นของจีนด้วย งงกะคู่มือเป็นภาษาต่างชาติหมด🙄😑
# actual: 7
# predicted: 4.862681853300807
#
# comment: ยังไม่ได้ลองการจัดส่งค่อนข้างช้า น้ำหนักเบา การใช้งานไม่น่าจะยาก ประสิทธิภาพต้องลองใช้ระยะหนึ่ง ดีกว่าไม่มีการกรองเลย
# actual: 4
# predicted: 4.852481315371476
#
# comment: ไม่ติด
# actual: 1
# predicted: 4.822108635248451
#
# comment: ใช้ไม่ได้ รูชาจไม่ดี
# actual: 5
# predicted: 4.7526242185172105
#
# comment: คุณภาพตามราคา
# actual: 3
# predicted: 4.726256535013227
#
# comment: ไม่ใช่ของJBLจริงๆ แต่ใช้ได้เสียงดีแบ่งเสียงข้างซ้าย-ขวา แบตหมดเร็ว ขนาดกะทัดรัดดี แอบใช้ยากนิดหน่อย ส่งของเร็ว
# actual: 4
# predicted: 4.698076131823711
#
# comment: ส่งช้าแต่รวมๆโอเคร
# actual: 3
# predicted: 4.696781251660755
#
# comment: แย่เสียงแตกจัดส่งช้ารอนานแถมลำโพงแตกอีก ติดต่อร้านไม่ได้
# actual: 6
# predicted: 4.692739267929523
#
# comment: กลิ่น: กลิ่นน้อย
# actual: 0
# predicted: 4.638641331221623
#
# comment: หูฟังได้ยินข้างเดียวไม่ดีเลย การแพคกล่องก็ไม่สมประกอบ ขาด
# actual: 5
# predicted: 4.63391471435108
#
# comment: ไม่ค่อยดังเท่าที่คาดหวัง และเสียงไม่คุ้มค่ากับราคาที่จ่ายไป ควรหลีกเลี่ยง
# actual: 7
# predicted: 4.599990817328584
#
# comment: ตั้งเวลาอะไรไม่ได้
# actual: 2
# predicted: 4.598781899524509
#
# comment: แย่  มาก  เสียงเหมือนมดตีกัน  แถบไม่ได้ยินเลย ฟังในมือถือดังหว่าด้วยซ้ำ
# actual: 9
# predicted: 4.588441085053356
#
# comment: พอใช้ระบบเสียงไม่ค่อยดี
# actual: 3
# predicted: 4.575651052170734
#
# comment: ไม่ได้มั้ยค่ะพี่เจนบอกว่าจะไปเยี่ยมบ้านเรามีแต่เรื่องที่บ้านพี่แบงค์มาบอกนะพี่ว่าจะเอาอะไรกับเราไปแล้วนะคะหนูอยาก
# actual: 0
# predicted: 4.537624260941111
#
# comment: ดี เเต่ส่งช้า
# actual: 3
# predicted: 4.5137185620614
#
# comment: สินค้าดูไม่ค่อยแข้งแรงเท่าไหร่ส่วนที่เหลือก็โอเคเลย
# actual: 5
# predicted: 4.512173897607578
#
# comment: เดือนเดียวเจ๊งครับ ใช้อะไรไม่ได้เลย
# actual: 5
# predicted: 4.507246005605394
#
# comment: ขอบคุณครับ
# actual: 0
# predicted: 4.478153319625801
#
# comment: ใช่งานดีคับยากอยู่นิดหนึ่งยากนิดหนึ่งคับ
# actual: 1
# predicted: 4.433030876387022
#
# comment: ส่งช้ามาก
# actual: 2
# predicted: 4.387094848619918
#
# comment: ไมค์ใช้งานไม่ได้
# actual: 3
# predicted: 4.364104814788805
#
# comment: ใช้ยากไปหน่อย ไม่ตรงตามคู่มือ ต้องงมวิธีทำเอง
# actual: 5
# predicted: 4.30583430800568
#
# comment: สภาพตามราคา
# actual: 2
# predicted: 4.221469680294013
#
# comment: ขนส่งแย่มากครับ
# actual: 4
# predicted: 4.167362095000293
#
# comment: ดีครับพอใช้
# actual: 2
# predicted: 3.9903090991190386
#
# comment: พอใช้ครับ
# actual: 0
# predicted: 3.9800632867647696
#
# comment: สั่งมา 2 ขวดยังไม่เคยลองใช้ยังไม่รู้ว่าถูกใจกลิ่นนี้หรือเปล่าแต่มีขวดนึงฝาบุบไม่แน่ใจว่าทำไมบุบดีที่ไม่แตก ฝากดูความเรียบร้อยอีกที
# actual: 3
# predicted: 3.788733033778735
#
# comment: มีตำหนิด้วยครับบุบไม่เหลื่อชิ้นดี
# actual: 3
# predicted: 3.7843456727546303
#
# comment: เสียงดังไม่ค่อยได้ยิน
# actual: 2
# predicted: 3.766221784353435
#
# comment: ทำยังไงให้ได้บ้างคะ
# actual: 0
# predicted: 3.7284494332999545
#
# comment: คุ้มราคามากสวยตรงปกนะคับ แต่..ติดที่ส่งช้าไปนะคับ
# actual: 5
# predicted: 3.4521417530662797
#
# comment: ใช้งานได้สองวัน ชาร์ทไฟไม่เข้าแล้ว
# actual: 6
# predicted: 3.1081454749578903
#
# comment: ดีนะเหมือนมีคอมใหม่5555 มันเลิส
# actual: 1
# predicted: 3.1075369596330984
#
# comment: ยังไม่ได้ลอง
# actual: 1
# predicted: 2.9420515458040883
#
# comment: เสียงเบามาก
# actual: 2
# predicted: 2.0
