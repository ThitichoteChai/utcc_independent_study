# %%
# %run data_read.py

X_train, X_test, y_train, y_test = train_test_split(data['comment'], data['score'], test_size=0.2, random_state=42)
# Out:
# Data path: C:\Users\POP PC\Documents\GitHub\utcc_independent_study\training\..\data\300_data_pop.xlsx
# data_size: 318
# variable: data train_data test_data

# %% [markdown]
# 1. Linear Model

# %%
pipeline_linear = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=thai_tokenizer)),
    ('regressor', LinearRegression())
])

param_grid_linear = {
    'regressor__fit_intercept': [True, False],
    'regressor__copy_X': [True, False]
}

# Define the grid search parameters
cv = 3  # Number of cross-validation folds

# Perform the grid search for Linear Regression
print('Performing grid search for Linear Regression...')
grid_search_linear = GridSearchCV(
    pipeline_linear,
    param_grid=param_grid_linear,
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# Fit the grid search object on the training data
grid_search_linear.fit(X_train, y_train)

# Print the best hyperparameters and corresponding mean test score
print(f'Best hyperparameters for Linear Regression: {grid_search_linear.best_params_}')
print(f'Mean test score: {grid_search_linear.best_score_:.4f}')

# Evaluate the best model on the test set
y_pred = grid_search_linear.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Linear Regression MSE on test set: {mse:.4f}')
print(f'Linear Regression MAE on test set: {mae:.4f}')

# Evaluate the best model on the test set and create DataFrame with results
result = pd.DataFrame({'comment': X_test,
                        'actual': y_test,
                        'predicted': grid_search_linear.predict(X_test)})
result['predicted'] = result['predicted'].clip(lower=0, upper=9)  # Clip predictions to valid score range of 0 to 1

# Print the DataFrame with results
sorted_df = result.sort_values(by='predicted', ascending=False)

for index, row in sorted_df.iterrows():
    print(f"comment: {row['comment']}")
    print(f"actual: {row['actual']}")
    print(f"predicted: {row['predicted']}")
    print('')
# Out:
# Performing grid search for Linear Regression...
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# E:\anaconda3\envs\utcc\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Best hyperparameters for Linear Regression: {'regressor__copy_X': True, 'regressor__fit_intercept': False}
# Mean test score: 0.4616
# Linear Regression MSE on test set: 3.0274
# Linear Regression MAE on test set: 1.3422
# comment: คุณภาพของสินค้าดีมาก ความคุ้มค่าดีมาก ความเร็วในการจัดส่งดีมากๆ การให้บริการจากร้านค้าดีมาก ถูกใจมากๆ ทุกอย่าง✨
# actual: 8
# predicted: 9.0
#
# comment: จัดส่งเร็วค่ะ ของได้ตรงรูปตรงปกทั้งเมาส์ทั้งแป้นพิมพ์ ส่วนตัวรู้สึกว่าแป้นพิมพ์บางไปหน่อยแต่ก็สมกับราคานี้ค่ะ มาที่เมาส์แนะนำว่าให้หาแผ่นรองเมาส์ด้วยนะคะสำหรับใครที่ไม่มี เพราะถ้าใช้กับโต๊ะเปล่าๆเลเซอร์จะไปติดค่ะ โดยรวมถือว่าดีคุ้มค่าทั้งราคาและระยะเวลาการส่งของค่ะ😊
# actual: 7
# predicted: 9.0
#
# comment: จัดส่งไวมากค่ะ ราคาก็ถูกดี เชื่อมต่อง่ายมาก เวลาใช้ค่อนข้างลื่น ไวค่ะ ก็ถนัดดี ไว้จะอุดหนุนใหม่นะคะ
# actual: 7
# predicted: 9.0
#
# comment: ก่อนซื้อก็อุตส่าห์ดูในรีวิวแล้วนะ ก็เห็นว่าเป็นปุ่มไทยแท้ แต่พอได้รับสินค้ามาก็รู้สึกผิดหวังมาก เป็นสติ๊กเกอร์ไทยซะงั้น ซึ่งพอติดสติ๊กเกอร์แล้ว มันมองไม่เห็นตัวอักษรเลย เวลาใช้งานกลางคืน ลำบากและหงุดหงิดมาก ซื้อแบบมีไฟ แต่ก็เหมือนไม่มีไฟ ช่างเป็นไฟที่ไร้ค่าเสียจริง ผิดหวังจริงๆ รู้งี้ ซื้อร้านอื่น ที่เป็นแป้นไทยแท้ดีกว่า
# actual: 8
# predicted: 8.927417252754722
#
# comment: ผมใช้iPhone14 Pro Max 512, มีเคสของcasetify. แม่เหล็กจับดีครับ ดีไซน์เีมาก แต่!!! ชาร์จบ้างไม่ชาร์จบ้าง ถอดเคสมาชาร์จก็เหมือนเดิม ไม่แนะนำให้หวังอะไรมากมายเลยครับ ถือสะว่าเอามาวางโทรศัพท์เฉยๆ ไม่แนะนำให้ซื้อถ้าคุณมีเคสหนา 1ดาวให้การบดีไซน์ นอกนั้นไม่ให้ดาวครับ
# actual: 9
# predicted: 8.844725488091385
#
# comment: ได้รับสินค้าเร็วมากภายในไม่กี่วัน เนื่องจากส่งจากในไทยเลย พัสดุกล่อง ยังไม่ได้แกะซองของสินค้า แต่คาดว่าน่าจะใช้งานได้ปกติ ไม่น่ามีปัญหาอะไร ประทับใจและจะกลับมาซื้ออีกครับ
# actual: 9
# predicted: 8.523896808888917
#
# comment: ได้รับของครบถ้วนค่ะ การจัดส่งไว สินค้าดูดี ราคาไม่แพง คุ้มค่ามากๆ ครั้งต่อไปสั่งอีกแน่นอนค่ะ สายสวยๆ น่ารักๆ
# actual: 7
# predicted: 8.438897619329024
#
# comment: สินคเาดีค่ะ ตรงปก ส่งไว แต่หัก1ดาวเพราะสั่งสีฟ้าไปแน่ว่สได้สรขาวมาแทน แต่ว่าไม่มีปัญหาค่ะ สามารถใช้ๆด้ปกติเลย โอเคมาก
# actual: 8
# predicted: 7.623145862054245
#
# comment: สั่งสินค้าไปสีม่วง แต่สีจริงที่ได้รับออกเป็นสีฟ้า ไม่ถูกใจเลย สินค้าใช้ได้ดี แต่คีย์บอร์ดสลับภาษาไม่รู้กดปุ่มไหน ดูตามที่แจ้ง แต่กดเปลี่ยนไม่ได้อ่ะ  งงมาก ส่งของเร็วพอใช้ได้
# actual: 6
# predicted: 7.608004614907897
#
# comment: แย่ ร้อนมากเวลาชาร์จ มีtype-c แต่ชาร์จออกไม่ได้ไม่รู้มีไว้เพื่ออะไร
# actual: 4
# predicted: 7.2088174376870775
#
# comment: สินค้ามาตรงปกค่ะ ลูกชอบมากค่ะมีสีสันสวยเวลาพิมพ์ ก็มีสีหลายสี ให้เลือก เวลาพิมพ์ง่ายไม่มีปัญหาในการใช้แป้นพิมพ์ค่ะ
# actual: 6
# predicted: 6.951583446151049
#
# comment: สังเกตดีๆมีรอยเหมือนถูกใช้งานมาแล้วด้วย มันค่อนข้างรู้สึกแย่และผิดหวังน่ะค่ะ แต่ก็ไม่ได้คาดหวังอะไรแต่แรกแล้ว ไม่รู้จะเชื่อมได้รึเปล่า🥲😭
# actual: 7
# predicted: 6.943681439759208
#
# comment: จากที่ลองใช้มาสักพักดีมากเสียงดีและชัดเสียงไม่แตกเบสหนักฟังเพลงเสียงดีมากมีตำหนินิดหน่อยตรงขอบแต่ไม่เป็นไรแบตทนมากชาร์จ1ครั้งตั้งแต่ได้มาวันแรกจนถึงวันนี้แบตยังเหลืออีก50เปอร์เซ็นต์
# actual: 7
# predicted: 6.817123572350945
#
# comment: ได้รับสินค้าแล้ว ชำรุดค่ะ แตก น่าจะห่อไม่ดีค่ะ ไม่ห่ออะไรเลย ใส่แค่ถุงมา แบบนี้ของก้อพังเสียหายหมดสิคะ
# actual: 6
# predicted: 6.710661538324676
#
# comment: สินค้าส่งมารวดเร็วทันใจดีมากค่ะ สินค้าส่งมาเรียบร้อยดีมากค่ะ สินค้าราคาถูกดีมากค่ะ สินค้าดีคุ้มค่ามากค่ะ
# actual: 7
# predicted: 6.701584161094922
#
# comment: ตะมุตะมิน่ารัก  เสียงแจ่มดีค่ะ  ชอบมาก  ราคาไม่แพงด้วย
# actual: 3
# predicted: 6.642656672657864
#
# comment: ส่งสินค้ารวดเร็วทันใจ ได้สินค้าตรตามที่สั่ง แพ็คเกจมีความเสียหายเล็กน้อยแตไม่มีผลกับสินค้า ราคาเหมาะสม โดยรวมแล้วถูกใจครับผม โอกาสหน้าค่อยซื้อเพิ่มนะครับ
# actual: 8
# predicted: 6.624485177249504
#
# comment: ส่งของช้ามา รอมาครึ่งเดือนพึ่งจะได้ ถ้าใครรีบไปที่อื่นครับ
# actual: 6
# predicted: 6.581996178619286
#
# comment: ดีค่ะ แต่เวลาโดนก็พอสง่ายเกินไปหน่อยค่ะ โดยรวมก็ใช้ง่าย พกพาง่ายสะดวกค่ะ แบตค่อนข้างอึดเลย เวลาเปิดปิดฝาก็ไม่ก๊อกแก๊ง ขนส่งไวค่ะ
# actual: 8
# predicted: 6.576966378148786
#
# comment: สินค้ามีคุณภาพ คุณภาพดี การจัดส่งค่อนข้างรวดเร็วค่ะ ภาพรวมโอเคเลย ได้มีม ถูกใจมากค่ะ สินค้าส่งออก บริหารโดยเ ขนส่งดีค่ะ
# actual: 6
# predicted: 6.502134035146664
#
# comment: รูปลักษณ์สวยงามตามปก แต่ตัวเรือนใหญ่ไปหน่อย การจัดส่งรวดเร็ว แต่ตอบเเช็ทช้ามาก เรื่องการใช้งานขอลองดูก่อนว่าจะใช้ได้ดีขนาดไหน
# actual: 5
# predicted: 6.4366957199139545
#
# comment: ได้รับสินค้าแล้วว ส่งก่อนกำหนด4วันเลย สินค้าตรงตามปก ราคาดีไม่แพง เคยใช้แล้วชอบ รู้สึกป้องกันลิปเปื้อนแมสได้ดี
# actual: 8
# predicted: 6.430929109638579
#
# comment: ทักทางร้านไม่ตอบ ในรูปตัวอย่างมีสายแจ๊ส ของมาถึงไม่มีไม่มีการบริการดูแล
# actual: 3
# predicted: 6.430339102656897
#
# comment: ใส่ซิมแล้วไม่มีสัญญาณ ข้อมูลการลงทะเบียนใช้งานไม่ได้ ร้านค้าตอบช้า
# actual: 7
# predicted: 6.222979987438641
#
# comment: ถือว่าดีกว่าที่คิดดลยครับราคาไมาเกินร้อยเสียงกำลังดีไม่ดังไปไม่เบาไป แต่เบสกับเสียงพอใช้ได้ไม่น่าเกรียดครับ
# actual: 6
# predicted: 6.025047318141826
#
# comment: สินค้าตรงปกจัดส่งเร็วมากๆถูกใจคุ้มค่าคุ้มราคาถูกใจครับผมร้านนี้สั่งเลยครับผ จัดส่งไวมากสั่งเลยครับร้านนี้ถูกใจมากๆคุ้มค่าคุ้มราคาราคาไม่แพงด้วย ม
# actual: 6
# predicted: 6.022242875471303
#
# comment: แพ๊คของแย่มาก กล่องสายบุบไปเกือบครึ่ง สั่งครั้งนี้ครั้งเดียวจะไม่สั่งอีกแล้ว
# actual: 6
# predicted: 6.011970740887296
#
# comment: ได้ของมาวันที่13 วันนี้สั่นค้างแล้วก็ดับไปเลย เปิดไม่ติดอีกเลย ลองชาร์จแล้วก็ไม่มีการตอบสนอง
# actual: 6
# predicted: 5.962871105819674
#
# comment: ดีมากๆ
# actual: 2
# predicted: 5.698170823656293
#
# comment: สั่งสีขาว แต่ส่งสีชมพูมาแทน ทางร้านไม่ถามก่อน รูปแบบทันสมัย จับถนัดมือ
# actual: 5
# predicted: 5.627831241734723
#
# comment: ชอบมากเลยดีไซน์เอยสีเอ่ยดีไปหมดดูเรียบแต่สวยสีดำสวยมากสีเทาก็สวยไว้จะสั่งสีเทาอีกค่ะทรงสวยเสียงดีไม่เจ็บหู
# actual: 7
# predicted: 5.611915582936107
#
# comment: ส่งไวมากวันเดียวถึงหัก1คะแนน เพราะไม่ห้อกันประแทก รวมแล้วคุ้ม
# actual: 4
# predicted: 5.549816401115228
#
# comment: โอเคนะคะก็สามารถชาร์จกับ Apple Watch ได้นะคะก็ถือว่าโอเคอยู่ไม่ได้เลวร้ายอะไรแต่เรื่องราคาก็ถือว่าแพงแต่ข้อดีก็คือไม่ต้องพรีออเดอร์มีของพร้อมส่งเลยนี่คือข้อดีของตัวนี้นะคะแต่ก็ใช้ได้นะคะแต่อาจจะรู้สึกก้องแก๊งค์ไปหน่อยจัดเต็มแน่นอนค่ะ
# actual: 7
# predicted: 5.465416759640696
#
# comment: สั่งสีดำได้สีน้ำเงิน บอกพนักงานส่งผิด แต่ดูจากรีวิวส่งผิดบ่อยไปนะคะ...
# actual: 5
# predicted: 5.202340871673902
#
# comment: ติดๆหลุดๆงงๆ ชาร์จเข้าบ้างไม่เข้าบ้าง เราใช้ไอโฟน11 นอย ตอนนี้ไม่ได้ใช้แล้ว ไม่แน่ใจเพราะ2เมตรรึป่าว ถ้า1เมตรอาจไม่มีปัญหา แพ็คดี ส่งไว
# actual: 7
# predicted: 5.0558523529177215
#
# comment: สภาพกล่องลำโพงเละเทะมากตั้งเเต่เเกะ ต้องชาร์จลำโพงตลอดเวลาถึงใช้ได้ บลูทูธหลุดบ่อย
# actual: 6
# predicted: 5.005687916345547
#
# comment: ให้สินค้ามาซ้ำและได้ไม่ครบ ไม่ได้จัดสินค้าตามที่สั่ง
# actual: 4
# predicted: 4.897713772968686
#
# comment: สวยดีค่ะแต่แบตหมดไวไปหน่อยเล่นไม่ค่อยเป็นด้วยงงๆนิสนึงใส่แล้ววัดไรไม่ค่อยตรงเท่าไหร่หรือเรางงๆไปเองก้อไม่รุ้เหมาะสมแก่ราคาค่ะลูกอยากได้ก้อเลยจัดให้ใช้ดูสักพักว่าจะทนทานมั้ย
# actual: 6
# predicted: 4.79026848459705
#
# comment: หูฟังได้ยินข้างเดียวไม่ดีเลย การแพคกล่องก็ไม่สมประกอบ ขาด
# actual: 5
# predicted: 4.661818658776025
#
# comment: เครื่องเล็กกว่าที่คิด เสียงไมค์พอใช้ได้ เสียงเพลงไม่ค่อยเท่าไหร่
# actual: 5
# predicted: 4.6191139143445135
#
# comment: ปุ่มกดด้านซ้ายเหมือนติดๆอะไรไม่รู้กดไม่ค่อยลง เลื่อนไม่ค่อยไป บลูทูธติดปกติแต่ไวไฟยังต่อไม่ได้เลย ไม่ค่อยคุ้มค่าเงิน
# actual: 7
# predicted: 4.401359576696443
#
# comment: ชาร์จช้ามากค่ะ ชาร์จตั้งแต่นอน ตื่นมายังไม่เต็มเลย
# actual: 5
# predicted: 4.298500128617135
#
# comment: คุณภาพดีเกินราคา ต้องสั่งอีกครับ
# actual: 5
# predicted: 4.290445569616644
#
# comment: ลองแล้วโอเค.ไฟติดทุกดวง.รีโมทใใช้ได้โอเคมีถ่านติิดมาแล้วใช้ได้เลย..ไฟสีสันสวยงาม. แพ็คของห่อส่งของดีสินค้าไม่มีเสียหาย.ได้รับของครบ. ตรงตามที่สั่งซื้อ. ขนส่งดีมีโทรแจ้งก่อนเข้ามาส่ง...
# actual: 7
# predicted: 3.8283495442540123
#
# comment: ไม่ได้ตรงกับความคาดหวัง แต่ก็ไม่แย่มาก
# actual: 0
# predicted: 3.8136374063030263
#
# comment: ไม่มีสายชาร์ตส่งมาด้วย
# actual: 3
# predicted: 3.45055774184432
#
# comment: รูปทรงเท่ดี วัสดุดี บางครั้งการใช้งานยังหน่วงบ้างนิดหน่อย แต่ก็ถือว่าสมราคา
# actual: 6
# predicted: 3.28258783589253
#
# comment: ไม่ได้ช่วยอะไรมากเลย
# actual: 1
# predicted: 3.266441410006828
#
# comment: ความคุ้มค่า: ดีสินค้าได้รับแล้วส่งมาจากต่างประเทศไม่มีความเสียหายขนส่งมีความทะนุถนอมดีลองทดลองใช้เดี๋ยวขอทดลองใช้ก่อนนะคะว่าเสียงดีไม่ดีแต่ราคาดีค่ะ
# actual: 6
# predicted: 3.141341122914512
#
# comment: กล่องเล็กถอดเข้าถอดออกยาก โทรไม่ค่อยเสถียร
# actual: 4
# predicted: 2.9617014115783515
#
# comment: สินค้าใช้การไม่ได้
# actual: 3
# predicted: 2.749494726386544
#
# comment: ของพึ่งได้มาเมื่อวานใช้ตอนเช้าฟังได้แค่ข้างเดียวผมรอของตั้งนานสุดท้ายฟังได้แค่ข้างขวา
# actual: 6
# predicted: 2.5327617338390014
#
# comment: สินค้าดีมีคุณภาพ
# actual: 2
# predicted: 2.4915667279375806
#
# comment: เสียงเบา​
# actual: 2
# predicted: 2.267427706838555
#
# comment: สินค้าดี สินค้ามาตรฐานตามราคา จัดส่งสินค้าเรว ดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดี ดีดีดีดีดีดีดีดีดีดีดีดี
# actual: 6
# predicted: 1.9758586812233423
#
# comment: เชื่อมต่อได้แค่ข้างเดียวคับ
# actual: 3
# predicted: 1.9724484153653814
#
# comment: ขนส่งแย่มากครับ
# actual: 3
# predicted: 1.9542075820805889
#
# comment: ได้หูฟังมาข้างเดียว
# actual: 4
# predicted: 1.8974684360491472
#
# comment: สภาพกล่องเยินนิดนึงแต่สินค้าด้านในยังโอเค เดี๋ยวลองใช้ดูก่อนว่าใช้ได้ปกติมั๊ย
# actual: 4
# predicted: 1.7067261092786832
#
# comment: ผิดหวังคนละรุ่นกันชาจไม่ใด้
# actual: 3
# predicted: 1.570615763762788
#
# comment: วัสดุก๊องแก๊งมาก สั่งสีชมพูได้สีฟ้า
# actual: 3
# predicted: 1.381111078201784
#
# comment: ไม่ควรซื้อ
# actual: 1
# predicted: 1.1914611906923163
#
# comment: พอใช้ได้
# actual: 1
# predicted: 0.9559692407698911
#
# comment: คุ้มค่าราคา
# actual: 1
# predicted: 0.0

# %% [markdown]
# 2. Support Vector Machine

# %%
# Define the pipeline and parameter search space for SVR
pipeline_svm = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=thai_tokenizer)),
    ('regressor', SVR())
])

param_grid_svm = {
    'regressor__kernel': ['linear', 'poly', 'rbf'],
    'regressor__C': [0.1, 1, 10],
    'regressor__gamma': ['scale', 'auto'],
}

# Perform the grid search for SVR
print('Performing grid search for SVR...')
grid_search_svm = GridSearchCV(
    pipeline_svm,
    param_grid=param_grid_svm,
    cv=3,
    n_jobs=-1,
    verbose=1
)

# Fit the grid search object on the training data
grid_search_svm.fit(X_train, y_train)

# Print the best hyperparameters and corresponding mean test score
print(f'Best hyperparameters for SVR: {grid_search_svm.best_params_}')
print(f'Mean test score: {grid_search_svm.best_score_:.4f}')

# Evaluate the best model on the test set
y_pred = grid_search_svm.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'SVM MSE on test set: {mse:.4f}')
print(f'SVM MAE on test set: {mae:.4f}')

# Evaluate the best model on the test set and create DataFrame with results
result = pd.DataFrame({'comment': X_test,
                        'actual': y_test,
                        'predicted': grid_search_svm.predict(X_test)})
result['predicted'] = result['predicted'].clip(lower=0, upper=9)  # Clip predictions to valid score range of 0 to 1

# Print the sorted DataFrame with results
sorted_df = result.sort_values(by='predicted', ascending=False)
for index, row in sorted_df.iterrows():
    print(f"comment: {row['comment']}")
    print(f"actual: {row['actual']}")
    print(f"predicted: {row['predicted']}")
    print('')
# Out:
# Performing grid search for SVR...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# E:\anaconda3\envs\utcc\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Best hyperparameters for SVR: {'regressor__C': 1, 'regressor__gamma': 'scale', 'regressor__kernel': 'linear'}
# Mean test score: 0.4728
# SVM MSE on test set: 2.3056
# SVM MAE on test set: 1.2300
# comment: ได้รับของครบถ้วนค่ะ การจัดส่งไว สินค้าดูดี ราคาไม่แพง คุ้มค่ามากๆ ครั้งต่อไปสั่งอีกแน่นอนค่ะ สายสวยๆ น่ารักๆ
# actual: 7
# predicted: 7.841295234528582
#
# comment: จัดส่งไวมากค่ะ ราคาก็ถูกดี เชื่อมต่อง่ายมาก เวลาใช้ค่อนข้างลื่น ไวค่ะ ก็ถนัดดี ไว้จะอุดหนุนใหม่นะคะ
# actual: 7
# predicted: 7.751694725532005
#
# comment: คุณภาพของสินค้าดีมาก ความคุ้มค่าดีมาก ความเร็วในการจัดส่งดีมากๆ การให้บริการจากร้านค้าดีมาก ถูกใจมากๆ ทุกอย่าง✨
# actual: 8
# predicted: 7.735275214921758
#
# comment: สินค้ามีคุณภาพ คุณภาพดี การจัดส่งค่อนข้างรวดเร็วค่ะ ภาพรวมโอเคเลย ได้มีม ถูกใจมากค่ะ สินค้าส่งออก บริหารโดยเ ขนส่งดีค่ะ
# actual: 6
# predicted: 7.364833830028081
#
# comment: จัดส่งเร็วค่ะ ของได้ตรงรูปตรงปกทั้งเมาส์ทั้งแป้นพิมพ์ ส่วนตัวรู้สึกว่าแป้นพิมพ์บางไปหน่อยแต่ก็สมกับราคานี้ค่ะ มาที่เมาส์แนะนำว่าให้หาแผ่นรองเมาส์ด้วยนะคะสำหรับใครที่ไม่มี เพราะถ้าใช้กับโต๊ะเปล่าๆเลเซอร์จะไปติดค่ะ โดยรวมถือว่าดีคุ้มค่าทั้งราคาและระยะเวลาการส่งของค่ะ😊
# actual: 7
# predicted: 7.209318033126657
#
# comment: สั่งสินค้าไปสีม่วง แต่สีจริงที่ได้รับออกเป็นสีฟ้า ไม่ถูกใจเลย สินค้าใช้ได้ดี แต่คีย์บอร์ดสลับภาษาไม่รู้กดปุ่มไหน ดูตามที่แจ้ง แต่กดเปลี่ยนไม่ได้อ่ะ  งงมาก ส่งของเร็วพอใช้ได้
# actual: 6
# predicted: 7.206775184598969
#
# comment: ก่อนซื้อก็อุตส่าห์ดูในรีวิวแล้วนะ ก็เห็นว่าเป็นปุ่มไทยแท้ แต่พอได้รับสินค้ามาก็รู้สึกผิดหวังมาก เป็นสติ๊กเกอร์ไทยซะงั้น ซึ่งพอติดสติ๊กเกอร์แล้ว มันมองไม่เห็นตัวอักษรเลย เวลาใช้งานกลางคืน ลำบากและหงุดหงิดมาก ซื้อแบบมีไฟ แต่ก็เหมือนไม่มีไฟ ช่างเป็นไฟที่ไร้ค่าเสียจริง ผิดหวังจริงๆ รู้งี้ ซื้อร้านอื่น ที่เป็นแป้นไทยแท้ดีกว่า
# actual: 8
# predicted: 7.176230533219357
#
# comment: ได้รับสินค้าเร็วมากภายในไม่กี่วัน เนื่องจากส่งจากในไทยเลย พัสดุกล่อง ยังไม่ได้แกะซองของสินค้า แต่คาดว่าน่าจะใช้งานได้ปกติ ไม่น่ามีปัญหาอะไร ประทับใจและจะกลับมาซื้ออีกครับ
# actual: 9
# predicted: 7.093796737727784
#
# comment: สินคเาดีค่ะ ตรงปก ส่งไว แต่หัก1ดาวเพราะสั่งสีฟ้าไปแน่ว่สได้สรขาวมาแทน แต่ว่าไม่มีปัญหาค่ะ สามารถใช้ๆด้ปกติเลย โอเคมาก
# actual: 8
# predicted: 6.85244381615912
#
# comment: ผมใช้iPhone14 Pro Max 512, มีเคสของcasetify. แม่เหล็กจับดีครับ ดีไซน์เีมาก แต่!!! ชาร์จบ้างไม่ชาร์จบ้าง ถอดเคสมาชาร์จก็เหมือนเดิม ไม่แนะนำให้หวังอะไรมากมายเลยครับ ถือสะว่าเอามาวางโทรศัพท์เฉยๆ ไม่แนะนำให้ซื้อถ้าคุณมีเคสหนา 1ดาวให้การบดีไซน์ นอกนั้นไม่ให้ดาวครับ
# actual: 9
# predicted: 6.816783630937829
#
# comment: ส่งสินค้ารวดเร็วทันใจ ได้สินค้าตรตามที่สั่ง แพ็คเกจมีความเสียหายเล็กน้อยแตไม่มีผลกับสินค้า ราคาเหมาะสม โดยรวมแล้วถูกใจครับผม โอกาสหน้าค่อยซื้อเพิ่มนะครับ
# actual: 8
# predicted: 6.782177107928906
#
# comment: ตะมุตะมิน่ารัก  เสียงแจ่มดีค่ะ  ชอบมาก  ราคาไม่แพงด้วย
# actual: 3
# predicted: 6.750077964324346
#
# comment: ดีค่ะ แต่เวลาโดนก็พอสง่ายเกินไปหน่อยค่ะ โดยรวมก็ใช้ง่าย พกพาง่ายสะดวกค่ะ แบตค่อนข้างอึดเลย เวลาเปิดปิดฝาก็ไม่ก๊อกแก๊ง ขนส่งไวค่ะ
# actual: 8
# predicted: 6.649979255610674
#
# comment: ได้รับสินค้าแล้วว ส่งก่อนกำหนด4วันเลย สินค้าตรงตามปก ราคาดีไม่แพง เคยใช้แล้วชอบ รู้สึกป้องกันลิปเปื้อนแมสได้ดี
# actual: 8
# predicted: 6.6455063757570585
#
# comment: ได้รับสินค้าแล้ว ชำรุดค่ะ แตก น่าจะห่อไม่ดีค่ะ ไม่ห่ออะไรเลย ใส่แค่ถุงมา แบบนี้ของก้อพังเสียหายหมดสิคะ
# actual: 6
# predicted: 6.563310410966663
#
# comment: ส่งของช้ามา รอมาครึ่งเดือนพึ่งจะได้ ถ้าใครรีบไปที่อื่นครับ
# actual: 6
# predicted: 6.510746786724107
#
# comment: สินค้าส่งมารวดเร็วทันใจดีมากค่ะ สินค้าส่งมาเรียบร้อยดีมากค่ะ สินค้าราคาถูกดีมากค่ะ สินค้าดีคุ้มค่ามากค่ะ
# actual: 7
# predicted: 6.477786401552805
#
# comment: สินค้ามาตรงปกค่ะ ลูกชอบมากค่ะมีสีสันสวยเวลาพิมพ์ ก็มีสีหลายสี ให้เลือก เวลาพิมพ์ง่ายไม่มีปัญหาในการใช้แป้นพิมพ์ค่ะ
# actual: 6
# predicted: 6.066974395927961
#
# comment: ใส่ซิมแล้วไม่มีสัญญาณ ข้อมูลการลงทะเบียนใช้งานไม่ได้ ร้านค้าตอบช้า
# actual: 7
# predicted: 6.059544792817401
#
# comment: สั่งสีขาว แต่ส่งสีชมพูมาแทน ทางร้านไม่ถามก่อน รูปแบบทันสมัย จับถนัดมือ
# actual: 5
# predicted: 6.008076713475037
#
# comment: ติดๆหลุดๆงงๆ ชาร์จเข้าบ้างไม่เข้าบ้าง เราใช้ไอโฟน11 นอย ตอนนี้ไม่ได้ใช้แล้ว ไม่แน่ใจเพราะ2เมตรรึป่าว ถ้า1เมตรอาจไม่มีปัญหา แพ็คดี ส่งไว
# actual: 7
# predicted: 5.912366934097648
#
# comment: สังเกตดีๆมีรอยเหมือนถูกใช้งานมาแล้วด้วย มันค่อนข้างรู้สึกแย่และผิดหวังน่ะค่ะ แต่ก็ไม่ได้คาดหวังอะไรแต่แรกแล้ว ไม่รู้จะเชื่อมได้รึเปล่า🥲😭
# actual: 7
# predicted: 5.882385785009558
#
# comment: รูปลักษณ์สวยงามตามปก แต่ตัวเรือนใหญ่ไปหน่อย การจัดส่งรวดเร็ว แต่ตอบเเช็ทช้ามาก เรื่องการใช้งานขอลองดูก่อนว่าจะใช้ได้ดีขนาดไหน
# actual: 5
# predicted: 5.694298768288251
#
# comment: สินค้าตรงปกจัดส่งเร็วมากๆถูกใจคุ้มค่าคุ้มราคาถูกใจครับผมร้านนี้สั่งเลยครับผ จัดส่งไวมากสั่งเลยครับร้านนี้ถูกใจมากๆคุ้มค่าคุ้มราคาราคาไม่แพงด้วย ม
# actual: 6
# predicted: 5.505171087940017
#
# comment: ทักทางร้านไม่ตอบ ในรูปตัวอย่างมีสายแจ๊ส ของมาถึงไม่มีไม่มีการบริการดูแล
# actual: 3
# predicted: 5.488561966222912
#
# comment: ได้ของมาวันที่13 วันนี้สั่นค้างแล้วก็ดับไปเลย เปิดไม่ติดอีกเลย ลองชาร์จแล้วก็ไม่มีการตอบสนอง
# actual: 6
# predicted: 5.408084828769228
#
# comment: ดีมากๆ
# actual: 2
# predicted: 5.298293206712688
#
# comment: หูฟังได้ยินข้างเดียวไม่ดีเลย การแพคกล่องก็ไม่สมประกอบ ขาด
# actual: 5
# predicted: 5.205893734526281
#
# comment: ถือว่าดีกว่าที่คิดดลยครับราคาไมาเกินร้อยเสียงกำลังดีไม่ดังไปไม่เบาไป แต่เบสกับเสียงพอใช้ได้ไม่น่าเกรียดครับ
# actual: 6
# predicted: 5.175571731338451
#
# comment: คุณภาพดีเกินราคา ต้องสั่งอีกครับ
# actual: 5
# predicted: 5.170341261008895
#
# comment: สภาพกล่องลำโพงเละเทะมากตั้งเเต่เเกะ ต้องชาร์จลำโพงตลอดเวลาถึงใช้ได้ บลูทูธหลุดบ่อย
# actual: 6
# predicted: 5.098436623174097
#
# comment: ส่งไวมากวันเดียวถึงหัก1คะแนน เพราะไม่ห้อกันประแทก รวมแล้วคุ้ม
# actual: 4
# predicted: 5.0673469793088195
#
# comment: ให้สินค้ามาซ้ำและได้ไม่ครบ ไม่ได้จัดสินค้าตามที่สั่ง
# actual: 4
# predicted: 5.065204522587273
#
# comment: โอเคนะคะก็สามารถชาร์จกับ Apple Watch ได้นะคะก็ถือว่าโอเคอยู่ไม่ได้เลวร้ายอะไรแต่เรื่องราคาก็ถือว่าแพงแต่ข้อดีก็คือไม่ต้องพรีออเดอร์มีของพร้อมส่งเลยนี่คือข้อดีของตัวนี้นะคะแต่ก็ใช้ได้นะคะแต่อาจจะรู้สึกก้องแก๊งค์ไปหน่อยจัดเต็มแน่นอนค่ะ
# actual: 7
# predicted: 4.96557487984666
#
# comment: จากที่ลองใช้มาสักพักดีมากเสียงดีและชัดเสียงไม่แตกเบสหนักฟังเพลงเสียงดีมากมีตำหนินิดหน่อยตรงขอบแต่ไม่เป็นไรแบตทนมากชาร์จ1ครั้งตั้งแต่ได้มาวันแรกจนถึงวันนี้แบตยังเหลืออีก50เปอร์เซ็นต์
# actual: 7
# predicted: 4.913008262589283
#
# comment: แย่ ร้อนมากเวลาชาร์จ มีtype-c แต่ชาร์จออกไม่ได้ไม่รู้มีไว้เพื่ออะไร
# actual: 4
# predicted: 4.903873659118204
#
# comment: ชาร์จช้ามากค่ะ ชาร์จตั้งแต่นอน ตื่นมายังไม่เต็มเลย
# actual: 5
# predicted: 4.886647013557617
#
# comment: สั่งสีดำได้สีน้ำเงิน บอกพนักงานส่งผิด แต่ดูจากรีวิวส่งผิดบ่อยไปนะคะ...
# actual: 5
# predicted: 4.867533748923924
#
# comment: แพ๊คของแย่มาก กล่องสายบุบไปเกือบครึ่ง สั่งครั้งนี้ครั้งเดียวจะไม่สั่งอีกแล้ว
# actual: 6
# predicted: 4.831142087370797
#
# comment: สวยดีค่ะแต่แบตหมดไวไปหน่อยเล่นไม่ค่อยเป็นด้วยงงๆนิสนึงใส่แล้ววัดไรไม่ค่อยตรงเท่าไหร่หรือเรางงๆไปเองก้อไม่รุ้เหมาะสมแก่ราคาค่ะลูกอยากได้ก้อเลยจัดให้ใช้ดูสักพักว่าจะทนทานมั้ย
# actual: 6
# predicted: 4.79435813323024
#
# comment: ลองแล้วโอเค.ไฟติดทุกดวง.รีโมทใใช้ได้โอเคมีถ่านติิดมาแล้วใช้ได้เลย..ไฟสีสันสวยงาม. แพ็คของห่อส่งของดีสินค้าไม่มีเสียหาย.ได้รับของครบ. ตรงตามที่สั่งซื้อ. ขนส่งดีมีโทรแจ้งก่อนเข้ามาส่ง...
# actual: 7
# predicted: 4.656532062808498
#
# comment: ไม่มีสายชาร์ตส่งมาด้วย
# actual: 3
# predicted: 4.4697601601614005
#
# comment: ปุ่มกดด้านซ้ายเหมือนติดๆอะไรไม่รู้กดไม่ค่อยลง เลื่อนไม่ค่อยไป บลูทูธติดปกติแต่ไวไฟยังต่อไม่ได้เลย ไม่ค่อยคุ้มค่าเงิน
# actual: 7
# predicted: 4.422136058986682
#
# comment: เครื่องเล็กกว่าที่คิด เสียงไมค์พอใช้ได้ เสียงเพลงไม่ค่อยเท่าไหร่
# actual: 5
# predicted: 4.408472292319789
#
# comment: รูปทรงเท่ดี วัสดุดี บางครั้งการใช้งานยังหน่วงบ้างนิดหน่อย แต่ก็ถือว่าสมราคา
# actual: 6
# predicted: 4.3980112076922495
#
# comment: ความคุ้มค่า: ดีสินค้าได้รับแล้วส่งมาจากต่างประเทศไม่มีความเสียหายขนส่งมีความทะนุถนอมดีลองทดลองใช้เดี๋ยวขอทดลองใช้ก่อนนะคะว่าเสียงดีไม่ดีแต่ราคาดีค่ะ
# actual: 6
# predicted: 4.24323725841378
#
# comment: สินค้าใช้การไม่ได้
# actual: 3
# predicted: 3.9915439781964297
#
# comment: ได้หูฟังมาข้างเดียว
# actual: 4
# predicted: 3.9721597817318344
#
# comment: วัสดุก๊องแก๊งมาก สั่งสีชมพูได้สีฟ้า
# actual: 3
# predicted: 3.822950337574426
#
# comment: ชอบมากเลยดีไซน์เอยสีเอ่ยดีไปหมดดูเรียบแต่สวยสีดำสวยมากสีเทาก็สวยไว้จะสั่งสีเทาอีกค่ะทรงสวยเสียงดีไม่เจ็บหู
# actual: 7
# predicted: 3.811950728674439
#
# comment: ไม่ได้ตรงกับความคาดหวัง แต่ก็ไม่แย่มาก
# actual: 0
# predicted: 3.6029083350917053
#
# comment: ของพึ่งได้มาเมื่อวานใช้ตอนเช้าฟังได้แค่ข้างเดียวผมรอของตั้งนานสุดท้ายฟังได้แค่ข้างขวา
# actual: 6
# predicted: 3.592949578211517
#
# comment: สภาพกล่องเยินนิดนึงแต่สินค้าด้านในยังโอเค เดี๋ยวลองใช้ดูก่อนว่าใช้ได้ปกติมั๊ย
# actual: 4
# predicted: 3.5753878391475626
#
# comment: สินค้าดีมีคุณภาพ
# actual: 2
# predicted: 3.4665327543633
#
# comment: สินค้าดี สินค้ามาตรฐานตามราคา จัดส่งสินค้าเรว ดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดี ดีดีดีดีดีดีดีดีดีดีดีดี
# actual: 6
# predicted: 3.415408191730452
#
# comment: เสียงเบา​
# actual: 2
# predicted: 3.272151550288165
#
# comment: เชื่อมต่อได้แค่ข้างเดียวคับ
# actual: 3
# predicted: 3.241612219030702
#
# comment: พอใช้ได้
# actual: 1
# predicted: 3.200085094531054
#
# comment: กล่องเล็กถอดเข้าถอดออกยาก โทรไม่ค่อยเสถียร
# actual: 4
# predicted: 3.024030687853315
#
# comment: ผิดหวังคนละรุ่นกันชาจไม่ใด้
# actual: 3
# predicted: 3.0176302926413974
#
# comment: ขนส่งแย่มากครับ
# actual: 3
# predicted: 2.8774445760995455
#
# comment: คุ้มค่าราคา
# actual: 1
# predicted: 2.6216052988944694
#
# comment: ไม่ได้ช่วยอะไรมากเลย
# actual: 1
# predicted: 2.5385872192135936
#
# comment: ไม่ควรซื้อ
# actual: 1
# predicted: 2.234013766716921

# %%
pipeline_tree = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=thai_tokenizer)),
    ('regressor', DecisionTreeRegressor())
])

param_grid_tree = {
    'regressor__max_depth': [5, 10, 20],
    'regressor__min_samples_split': [2, 5, 10]
}

# Perform the grid search for DecisionTreeRegressor
print('Performing grid search for DecisionTreeRegressor...')
grid_search_tree = GridSearchCV(
    pipeline_tree,
    param_grid=param_grid_tree,
    cv=3,
    n_jobs=-1,
    verbose=1
)

# Fit the grid search object on the training data
grid_search_tree.fit(X_train, y_train)

# Print the best hyperparameters and corresponding mean test score
print(f'Best hyperparameters for DecisionTreeRegressor: {grid_search_tree.best_params_}')
print(f'Mean test score: {grid_search_tree.best_score_:.4f}')

# Evaluate the best model on the test set
y_pred = grid_search_tree.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'DecisionTreeRegressor MSE on test set: {mse:.4f}')
print(f'DecisionTreeRegressor MAE on test set: {mae:.4f}')

# Evaluate the best model on the test set and create DataFrame with results
result = pd.DataFrame({'comment': X_test,
                        'actual': y_test,
                        'predicted': grid_search_tree.predict(X_test)})
result['predicted'] = result['predicted'].clip(lower=0, upper=9)  # Clip predictions to valid score range of 0 to 1

# Print the sorted DataFrame with results
sorted_df = result.sort_values(by='predicted', ascending=False)
for index, row in sorted_df.iterrows():
    print(f"comment: {row['comment']}")
    print(f"actual: {row['actual']}")
    print(f"predicted: {row['predicted']}")
    print('')
# Out:
# Performing grid search for DecisionTreeRegressor...
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# E:\anaconda3\envs\utcc\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Best hyperparameters for DecisionTreeRegressor: {'regressor__max_depth': 5, 'regressor__min_samples_split': 10}
# Mean test score: 0.3172
# DecisionTreeRegressor MSE on test set: 4.5369
# DecisionTreeRegressor MAE on test set: 1.5624
# comment: ตะมุตะมิน่ารัก  เสียงแจ่มดีค่ะ  ชอบมาก  ราคาไม่แพงด้วย
# actual: 3
# predicted: 9.0
#
# comment: ได้รับสินค้าแล้วว ส่งก่อนกำหนด4วันเลย สินค้าตรงตามปก ราคาดีไม่แพง เคยใช้แล้วชอบ รู้สึกป้องกันลิปเปื้อนแมสได้ดี
# actual: 8
# predicted: 9.0
#
# comment: ได้รับของครบถ้วนค่ะ การจัดส่งไว สินค้าดูดี ราคาไม่แพง คุ้มค่ามากๆ ครั้งต่อไปสั่งอีกแน่นอนค่ะ สายสวยๆ น่ารักๆ
# actual: 7
# predicted: 8.75
#
# comment: คุณภาพของสินค้าดีมาก ความคุ้มค่าดีมาก ความเร็วในการจัดส่งดีมากๆ การให้บริการจากร้านค้าดีมาก ถูกใจมากๆ ทุกอย่าง✨
# actual: 8
# predicted: 8.333333333333334
#
# comment: ชาร์จช้ามากค่ะ ชาร์จตั้งแต่นอน ตื่นมายังไม่เต็มเลย
# actual: 5
# predicted: 7.454545454545454
#
# comment: จากที่ลองใช้มาสักพักดีมากเสียงดีและชัดเสียงไม่แตกเบสหนักฟังเพลงเสียงดีมากมีตำหนินิดหน่อยตรงขอบแต่ไม่เป็นไรแบตทนมากชาร์จ1ครั้งตั้งแต่ได้มาวันแรกจนถึงวันนี้แบตยังเหลืออีก50เปอร์เซ็นต์
# actual: 7
# predicted: 7.25
#
# comment: ให้สินค้ามาซ้ำและได้ไม่ครบ ไม่ได้จัดสินค้าตามที่สั่ง
# actual: 4
# predicted: 7.25
#
# comment: จัดส่งเร็วค่ะ ของได้ตรงรูปตรงปกทั้งเมาส์ทั้งแป้นพิมพ์ ส่วนตัวรู้สึกว่าแป้นพิมพ์บางไปหน่อยแต่ก็สมกับราคานี้ค่ะ มาที่เมาส์แนะนำว่าให้หาแผ่นรองเมาส์ด้วยนะคะสำหรับใครที่ไม่มี เพราะถ้าใช้กับโต๊ะเปล่าๆเลเซอร์จะไปติดค่ะ โดยรวมถือว่าดีคุ้มค่าทั้งราคาและระยะเวลาการส่งของค่ะ😊
# actual: 7
# predicted: 7.111111111111111
#
# comment: ใส่ซิมแล้วไม่มีสัญญาณ ข้อมูลการลงทะเบียนใช้งานไม่ได้ ร้านค้าตอบช้า
# actual: 7
# predicted: 7.111111111111111
#
# comment: ได้ของมาวันที่13 วันนี้สั่นค้างแล้วก็ดับไปเลย เปิดไม่ติดอีกเลย ลองชาร์จแล้วก็ไม่มีการตอบสนอง
# actual: 6
# predicted: 7.111111111111111
#
# comment: สินค้ามาตรงปกค่ะ ลูกชอบมากค่ะมีสีสันสวยเวลาพิมพ์ ก็มีสีหลายสี ให้เลือก เวลาพิมพ์ง่ายไม่มีปัญหาในการใช้แป้นพิมพ์ค่ะ
# actual: 6
# predicted: 7.111111111111111
#
# comment: หูฟังได้ยินข้างเดียวไม่ดีเลย การแพคกล่องก็ไม่สมประกอบ ขาด
# actual: 5
# predicted: 7.111111111111111
#
# comment: จัดส่งไวมากค่ะ ราคาก็ถูกดี เชื่อมต่อง่ายมาก เวลาใช้ค่อนข้างลื่น ไวค่ะ ก็ถนัดดี ไว้จะอุดหนุนใหม่นะคะ
# actual: 7
# predicted: 7.022222222222222
#
# comment: สินค้ามีคุณภาพ คุณภาพดี การจัดส่งค่อนข้างรวดเร็วค่ะ ภาพรวมโอเคเลย ได้มีม ถูกใจมากค่ะ สินค้าส่งออก บริหารโดยเ ขนส่งดีค่ะ
# actual: 6
# predicted: 7.022222222222222
#
# comment: ได้รับสินค้าเร็วมากภายในไม่กี่วัน เนื่องจากส่งจากในไทยเลย พัสดุกล่อง ยังไม่ได้แกะซองของสินค้า แต่คาดว่าน่าจะใช้งานได้ปกติ ไม่น่ามีปัญหาอะไร ประทับใจและจะกลับมาซื้ออีกครับ
# actual: 9
# predicted: 7.022222222222222
#
# comment: ส่งสินค้ารวดเร็วทันใจ ได้สินค้าตรตามที่สั่ง แพ็คเกจมีความเสียหายเล็กน้อยแตไม่มีผลกับสินค้า ราคาเหมาะสม โดยรวมแล้วถูกใจครับผม โอกาสหน้าค่อยซื้อเพิ่มนะครับ
# actual: 8
# predicted: 7.022222222222222
#
# comment: ผมใช้iPhone14 Pro Max 512, มีเคสของcasetify. แม่เหล็กจับดีครับ ดีไซน์เีมาก แต่!!! ชาร์จบ้างไม่ชาร์จบ้าง ถอดเคสมาชาร์จก็เหมือนเดิม ไม่แนะนำให้หวังอะไรมากมายเลยครับ ถือสะว่าเอามาวางโทรศัพท์เฉยๆ ไม่แนะนำให้ซื้อถ้าคุณมีเคสหนา 1ดาวให้การบดีไซน์ นอกนั้นไม่ให้ดาวครับ
# actual: 9
# predicted: 7.022222222222222
#
# comment: สินคเาดีค่ะ ตรงปก ส่งไว แต่หัก1ดาวเพราะสั่งสีฟ้าไปแน่ว่สได้สรขาวมาแทน แต่ว่าไม่มีปัญหาค่ะ สามารถใช้ๆด้ปกติเลย โอเคมาก
# actual: 8
# predicted: 7.022222222222222
#
# comment: สั่งสีขาว แต่ส่งสีชมพูมาแทน ทางร้านไม่ถามก่อน รูปแบบทันสมัย จับถนัดมือ
# actual: 5
# predicted: 7.022222222222222
#
# comment: ได้รับสินค้าแล้ว ชำรุดค่ะ แตก น่าจะห่อไม่ดีค่ะ ไม่ห่ออะไรเลย ใส่แค่ถุงมา แบบนี้ของก้อพังเสียหายหมดสิคะ
# actual: 6
# predicted: 7.022222222222222
#
# comment: สั่งสินค้าไปสีม่วง แต่สีจริงที่ได้รับออกเป็นสีฟ้า ไม่ถูกใจเลย สินค้าใช้ได้ดี แต่คีย์บอร์ดสลับภาษาไม่รู้กดปุ่มไหน ดูตามที่แจ้ง แต่กดเปลี่ยนไม่ได้อ่ะ  งงมาก ส่งของเร็วพอใช้ได้
# actual: 6
# predicted: 7.022222222222222
#
# comment: ก่อนซื้อก็อุตส่าห์ดูในรีวิวแล้วนะ ก็เห็นว่าเป็นปุ่มไทยแท้ แต่พอได้รับสินค้ามาก็รู้สึกผิดหวังมาก เป็นสติ๊กเกอร์ไทยซะงั้น ซึ่งพอติดสติ๊กเกอร์แล้ว มันมองไม่เห็นตัวอักษรเลย เวลาใช้งานกลางคืน ลำบากและหงุดหงิดมาก ซื้อแบบมีไฟ แต่ก็เหมือนไม่มีไฟ ช่างเป็นไฟที่ไร้ค่าเสียจริง ผิดหวังจริงๆ รู้งี้ ซื้อร้านอื่น ที่เป็นแป้นไทยแท้ดีกว่า
# actual: 8
# predicted: 7.022222222222222
#
# comment: ติดๆหลุดๆงงๆ ชาร์จเข้าบ้างไม่เข้าบ้าง เราใช้ไอโฟน11 นอย ตอนนี้ไม่ได้ใช้แล้ว ไม่แน่ใจเพราะ2เมตรรึป่าว ถ้า1เมตรอาจไม่มีปัญหา แพ็คดี ส่งไว
# actual: 7
# predicted: 7.022222222222222
#
# comment: ความคุ้มค่า: ดีสินค้าได้รับแล้วส่งมาจากต่างประเทศไม่มีความเสียหายขนส่งมีความทะนุถนอมดีลองทดลองใช้เดี๋ยวขอทดลองใช้ก่อนนะคะว่าเสียงดีไม่ดีแต่ราคาดีค่ะ
# actual: 6
# predicted: 6.875
#
# comment: สวยดีค่ะแต่แบตหมดไวไปหน่อยเล่นไม่ค่อยเป็นด้วยงงๆนิสนึงใส่แล้ววัดไรไม่ค่อยตรงเท่าไหร่หรือเรางงๆไปเองก้อไม่รุ้เหมาะสมแก่ราคาค่ะลูกอยากได้ก้อเลยจัดให้ใช้ดูสักพักว่าจะทนทานมั้ย
# actual: 6
# predicted: 6.875
#
# comment: สินค้าตรงปกจัดส่งเร็วมากๆถูกใจคุ้มค่าคุ้มราคาถูกใจครับผมร้านนี้สั่งเลยครับผ จัดส่งไวมากสั่งเลยครับร้านนี้ถูกใจมากๆคุ้มค่าคุ้มราคาราคาไม่แพงด้วย ม
# actual: 6
# predicted: 5.75
#
# comment: สังเกตดีๆมีรอยเหมือนถูกใช้งานมาแล้วด้วย มันค่อนข้างรู้สึกแย่และผิดหวังน่ะค่ะ แต่ก็ไม่ได้คาดหวังอะไรแต่แรกแล้ว ไม่รู้จะเชื่อมได้รึเปล่า🥲😭
# actual: 7
# predicted: 5.575
#
# comment: รูปทรงเท่ดี วัสดุดี บางครั้งการใช้งานยังหน่วงบ้างนิดหน่อย แต่ก็ถือว่าสมราคา
# actual: 6
# predicted: 5.575
#
# comment: เครื่องเล็กกว่าที่คิด เสียงไมค์พอใช้ได้ เสียงเพลงไม่ค่อยเท่าไหร่
# actual: 5
# predicted: 5.575
#
# comment: แย่ ร้อนมากเวลาชาร์จ มีtype-c แต่ชาร์จออกไม่ได้ไม่รู้มีไว้เพื่ออะไร
# actual: 4
# predicted: 5.575
#
# comment: ส่งของช้ามา รอมาครึ่งเดือนพึ่งจะได้ ถ้าใครรีบไปที่อื่นครับ
# actual: 6
# predicted: 5.575
#
# comment: ส่งไวมากวันเดียวถึงหัก1คะแนน เพราะไม่ห้อกันประแทก รวมแล้วคุ้ม
# actual: 4
# predicted: 5.575
#
# comment: รูปลักษณ์สวยงามตามปก แต่ตัวเรือนใหญ่ไปหน่อย การจัดส่งรวดเร็ว แต่ตอบเเช็ทช้ามาก เรื่องการใช้งานขอลองดูก่อนว่าจะใช้ได้ดีขนาดไหน
# actual: 5
# predicted: 5.575
#
# comment: ดีค่ะ แต่เวลาโดนก็พอสง่ายเกินไปหน่อยค่ะ โดยรวมก็ใช้ง่าย พกพาง่ายสะดวกค่ะ แบตค่อนข้างอึดเลย เวลาเปิดปิดฝาก็ไม่ก๊อกแก๊ง ขนส่งไวค่ะ
# actual: 8
# predicted: 4.0
#
# comment: ลองแล้วโอเค.ไฟติดทุกดวง.รีโมทใใช้ได้โอเคมีถ่านติิดมาแล้วใช้ได้เลย..ไฟสีสันสวยงาม. แพ็คของห่อส่งของดีสินค้าไม่มีเสียหาย.ได้รับของครบ. ตรงตามที่สั่งซื้อ. ขนส่งดีมีโทรแจ้งก่อนเข้ามาส่ง...
# actual: 7
# predicted: 3.2
#
# comment: สภาพกล่องเยินนิดนึงแต่สินค้าด้านในยังโอเค เดี๋ยวลองใช้ดูก่อนว่าใช้ได้ปกติมั๊ย
# actual: 4
# predicted: 3.0
#
# comment: สั่งสีดำได้สีน้ำเงิน บอกพนักงานส่งผิด แต่ดูจากรีวิวส่งผิดบ่อยไปนะคะ...
# actual: 5
# predicted: 3.0
#
# comment: ขนส่งแย่มากครับ
# actual: 3
# predicted: 3.0
#
# comment: สินค้าใช้การไม่ได้
# actual: 3
# predicted: 3.0
#
# comment: ได้หูฟังมาข้างเดียว
# actual: 4
# predicted: 3.0
#
# comment: ทักทางร้านไม่ตอบ ในรูปตัวอย่างมีสายแจ๊ส ของมาถึงไม่มีไม่มีการบริการดูแล
# actual: 3
# predicted: 3.0
#
# comment: สินค้าดี สินค้ามาตรฐานตามราคา จัดส่งสินค้าเรว ดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดี ดีดีดีดีดีดีดีดีดีดีดีดี
# actual: 6
# predicted: 3.0
#
# comment: พอใช้ได้
# actual: 1
# predicted: 3.0
#
# comment: ปุ่มกดด้านซ้ายเหมือนติดๆอะไรไม่รู้กดไม่ค่อยลง เลื่อนไม่ค่อยไป บลูทูธติดปกติแต่ไวไฟยังต่อไม่ได้เลย ไม่ค่อยคุ้มค่าเงิน
# actual: 7
# predicted: 3.0
#
# comment: เสียงเบา​
# actual: 2
# predicted: 3.0
#
# comment: ไม่มีสายชาร์ตส่งมาด้วย
# actual: 3
# predicted: 3.0
#
# comment: กล่องเล็กถอดเข้าถอดออกยาก โทรไม่ค่อยเสถียร
# actual: 4
# predicted: 3.0
#
# comment: ของพึ่งได้มาเมื่อวานใช้ตอนเช้าฟังได้แค่ข้างเดียวผมรอของตั้งนานสุดท้ายฟังได้แค่ข้างขวา
# actual: 6
# predicted: 3.0
#
# comment: ถือว่าดีกว่าที่คิดดลยครับราคาไมาเกินร้อยเสียงกำลังดีไม่ดังไปไม่เบาไป แต่เบสกับเสียงพอใช้ได้ไม่น่าเกรียดครับ
# actual: 6
# predicted: 3.0
#
# comment: ไม่ได้ช่วยอะไรมากเลย
# actual: 1
# predicted: 3.0
#
# comment: เชื่อมต่อได้แค่ข้างเดียวคับ
# actual: 3
# predicted: 3.0
#
# comment: แพ๊คของแย่มาก กล่องสายบุบไปเกือบครึ่ง สั่งครั้งนี้ครั้งเดียวจะไม่สั่งอีกแล้ว
# actual: 6
# predicted: 3.0
#
# comment: ดีมากๆ
# actual: 2
# predicted: 3.0
#
# comment: สภาพกล่องลำโพงเละเทะมากตั้งเเต่เเกะ ต้องชาร์จลำโพงตลอดเวลาถึงใช้ได้ บลูทูธหลุดบ่อย
# actual: 6
# predicted: 3.0
#
# comment: ไม่ควรซื้อ
# actual: 1
# predicted: 3.0
#
# comment: สินค้าดีมีคุณภาพ
# actual: 2
# predicted: 3.0
#
# comment: ผิดหวังคนละรุ่นกันชาจไม่ใด้
# actual: 3
# predicted: 3.0
#
# comment: ชอบมากเลยดีไซน์เอยสีเอ่ยดีไปหมดดูเรียบแต่สวยสีดำสวยมากสีเทาก็สวยไว้จะสั่งสีเทาอีกค่ะทรงสวยเสียงดีไม่เจ็บหู
# actual: 7
# predicted: 3.0
#
# comment: สินค้าส่งมารวดเร็วทันใจดีมากค่ะ สินค้าส่งมาเรียบร้อยดีมากค่ะ สินค้าราคาถูกดีมากค่ะ สินค้าดีคุ้มค่ามากค่ะ
# actual: 7
# predicted: 3.0
#
# comment: คุณภาพดีเกินราคา ต้องสั่งอีกครับ
# actual: 5
# predicted: 3.0
#
# comment: วัสดุก๊องแก๊งมาก สั่งสีชมพูได้สีฟ้า
# actual: 3
# predicted: 3.0
#
# comment: คุ้มค่าราคา
# actual: 1
# predicted: 3.0
#
# comment: ไม่ได้ตรงกับความคาดหวัง แต่ก็ไม่แย่มาก
# actual: 0
# predicted: 0.25
#
# comment: โอเคนะคะก็สามารถชาร์จกับ Apple Watch ได้นะคะก็ถือว่าโอเคอยู่ไม่ได้เลวร้ายอะไรแต่เรื่องราคาก็ถือว่าแพงแต่ข้อดีก็คือไม่ต้องพรีออเดอร์มีของพร้อมส่งเลยนี่คือข้อดีของตัวนี้นะคะแต่ก็ใช้ได้นะคะแต่อาจจะรู้สึกก้องแก๊งค์ไปหน่อยจัดเต็มแน่นอนค่ะ
# actual: 7
# predicted: 0.25

# %%
pipeline_knn = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=thai_tokenizer)),
    ('regressor', KNeighborsRegressor())
])

param_grid_knn = {
    'regressor__n_neighbors': [5, 10, 15],
    'regressor__weights': ['uniform', 'distance'],
    'regressor__p': [1, 2]
}

# Perform the grid search for KNeighborsRegressor
print('Performing grid search for KNeighborsRegressor...')
grid_search_knn = GridSearchCV(
    pipeline_knn,
    param_grid=param_grid_knn,
    cv=3,
    n_jobs=-1,
    verbose=1
)

# Fit the grid search object on the training data
grid_search_knn.fit(X_train, y_train)

# Print the best hyperparameters and corresponding mean test score
print(f'Best hyperparameters for KNeighborsRegressor: {grid_search_knn.best_params_}')
print(f'Mean test score: {grid_search_knn.best_score_:.4f}')

# Evaluate the best model on the test set
y_pred = grid_search_knn.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'KNeighborsRegressor MSE on test set: {mse:.4f}')
print(f'KNeighborsRegressor MAE on test set: {mae:.4f}')

# Evaluate the best model on the test set and create DataFrame with results
result = pd.DataFrame({'comment': X_test,
                        'actual': y_test,
                        'predicted': grid_search_knn.predict(X_test)})
result['predicted'] = result['predicted'].clip(lower=0, upper=9)  # Clip predictions to valid score range of 0 to 1

# Print the sorted DataFrame with results
sorted_df = result.sort_values(by='predicted', ascending=False)
for index, row in sorted_df.iterrows():
    print(f"comment: {row['comment']}")
    print(f"actual: {row['actual']}")
    print(f"predicted: {row['predicted']}")
    print('')
# Out:
# Performing grid search for KNeighborsRegressor...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# E:\anaconda3\envs\utcc\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Best hyperparameters for KNeighborsRegressor: {'regressor__n_neighbors': 5, 'regressor__p': 2, 'regressor__weights': 'distance'}
# Mean test score: 0.1307
# KNeighborsRegressor MSE on test set: 4.1410
# KNeighborsRegressor MAE on test set: 1.5667
# comment: ได้รับสินค้าแล้วว ส่งก่อนกำหนด4วันเลย สินค้าตรงตามปก ราคาดีไม่แพง เคยใช้แล้วชอบ รู้สึกป้องกันลิปเปื้อนแมสได้ดี
# actual: 8
# predicted: 8.403383524066054
#
# comment: ก่อนซื้อก็อุตส่าห์ดูในรีวิวแล้วนะ ก็เห็นว่าเป็นปุ่มไทยแท้ แต่พอได้รับสินค้ามาก็รู้สึกผิดหวังมาก เป็นสติ๊กเกอร์ไทยซะงั้น ซึ่งพอติดสติ๊กเกอร์แล้ว มันมองไม่เห็นตัวอักษรเลย เวลาใช้งานกลางคืน ลำบากและหงุดหงิดมาก ซื้อแบบมีไฟ แต่ก็เหมือนไม่มีไฟ ช่างเป็นไฟที่ไร้ค่าเสียจริง ผิดหวังจริงๆ รู้งี้ ซื้อร้านอื่น ที่เป็นแป้นไทยแท้ดีกว่า
# actual: 8
# predicted: 8.18639027719487
#
# comment: คุณภาพของสินค้าดีมาก ความคุ้มค่าดีมาก ความเร็วในการจัดส่งดีมากๆ การให้บริการจากร้านค้าดีมาก ถูกใจมากๆ ทุกอย่าง✨
# actual: 8
# predicted: 8.017598986989137
#
# comment: ส่งสินค้ารวดเร็วทันใจ ได้สินค้าตรตามที่สั่ง แพ็คเกจมีความเสียหายเล็กน้อยแตไม่มีผลกับสินค้า ราคาเหมาะสม โดยรวมแล้วถูกใจครับผม โอกาสหน้าค่อยซื้อเพิ่มนะครับ
# actual: 8
# predicted: 7.999421707323831
#
# comment: ได้รับสินค้าเร็วมากภายในไม่กี่วัน เนื่องจากส่งจากในไทยเลย พัสดุกล่อง ยังไม่ได้แกะซองของสินค้า แต่คาดว่าน่าจะใช้งานได้ปกติ ไม่น่ามีปัญหาอะไร ประทับใจและจะกลับมาซื้ออีกครับ
# actual: 9
# predicted: 7.783949134766491
#
# comment: สินค้ามีคุณภาพ คุณภาพดี การจัดส่งค่อนข้างรวดเร็วค่ะ ภาพรวมโอเคเลย ได้มีม ถูกใจมากค่ะ สินค้าส่งออก บริหารโดยเ ขนส่งดีค่ะ
# actual: 6
# predicted: 7.627370638932582
#
# comment: ได้รับของครบถ้วนค่ะ การจัดส่งไว สินค้าดูดี ราคาไม่แพง คุ้มค่ามากๆ ครั้งต่อไปสั่งอีกแน่นอนค่ะ สายสวยๆ น่ารักๆ
# actual: 7
# predicted: 7.4134396106410385
#
# comment: สินค้าส่งมารวดเร็วทันใจดีมากค่ะ สินค้าส่งมาเรียบร้อยดีมากค่ะ สินค้าราคาถูกดีมากค่ะ สินค้าดีคุ้มค่ามากค่ะ
# actual: 7
# predicted: 7.403424960882528
#
# comment: ได้รับสินค้าแล้ว ชำรุดค่ะ แตก น่าจะห่อไม่ดีค่ะ ไม่ห่ออะไรเลย ใส่แค่ถุงมา แบบนี้ของก้อพังเสียหายหมดสิคะ
# actual: 6
# predicted: 7.206504252493205
#
# comment: จัดส่งเร็วค่ะ ของได้ตรงรูปตรงปกทั้งเมาส์ทั้งแป้นพิมพ์ ส่วนตัวรู้สึกว่าแป้นพิมพ์บางไปหน่อยแต่ก็สมกับราคานี้ค่ะ มาที่เมาส์แนะนำว่าให้หาแผ่นรองเมาส์ด้วยนะคะสำหรับใครที่ไม่มี เพราะถ้าใช้กับโต๊ะเปล่าๆเลเซอร์จะไปติดค่ะ โดยรวมถือว่าดีคุ้มค่าทั้งราคาและระยะเวลาการส่งของค่ะ😊
# actual: 7
# predicted: 7.20443513275551
#
# comment: ดีมากๆ
# actual: 2
# predicted: 7.0479452167010415
#
# comment: สั่งสินค้าไปสีม่วง แต่สีจริงที่ได้รับออกเป็นสีฟ้า ไม่ถูกใจเลย สินค้าใช้ได้ดี แต่คีย์บอร์ดสลับภาษาไม่รู้กดปุ่มไหน ดูตามที่แจ้ง แต่กดเปลี่ยนไม่ได้อ่ะ  งงมาก ส่งของเร็วพอใช้ได้
# actual: 6
# predicted: 7.006369413251368
#
# comment: โอเคนะคะก็สามารถชาร์จกับ Apple Watch ได้นะคะก็ถือว่าโอเคอยู่ไม่ได้เลวร้ายอะไรแต่เรื่องราคาก็ถือว่าแพงแต่ข้อดีก็คือไม่ต้องพรีออเดอร์มีของพร้อมส่งเลยนี่คือข้อดีของตัวนี้นะคะแต่ก็ใช้ได้นะคะแต่อาจจะรู้สึกก้องแก๊งค์ไปหน่อยจัดเต็มแน่นอนค่ะ
# actual: 7
# predicted: 6.9931493218778575
#
# comment: ตะมุตะมิน่ารัก  เสียงแจ่มดีค่ะ  ชอบมาก  ราคาไม่แพงด้วย
# actual: 3
# predicted: 6.970731997650234
#
# comment: จัดส่งไวมากค่ะ ราคาก็ถูกดี เชื่อมต่อง่ายมาก เวลาใช้ค่อนข้างลื่น ไวค่ะ ก็ถนัดดี ไว้จะอุดหนุนใหม่นะคะ
# actual: 7
# predicted: 6.808623362977193
#
# comment: ชาร์จช้ามากค่ะ ชาร์จตั้งแต่นอน ตื่นมายังไม่เต็มเลย
# actual: 5
# predicted: 6.799982558386524
#
# comment: ติดๆหลุดๆงงๆ ชาร์จเข้าบ้างไม่เข้าบ้าง เราใช้ไอโฟน11 นอย ตอนนี้ไม่ได้ใช้แล้ว ไม่แน่ใจเพราะ2เมตรรึป่าว ถ้า1เมตรอาจไม่มีปัญหา แพ็คดี ส่งไว
# actual: 7
# predicted: 6.769360217652396
#
# comment: ส่งไวมากวันเดียวถึงหัก1คะแนน เพราะไม่ห้อกันประแทก รวมแล้วคุ้ม
# actual: 4
# predicted: 6.554719620646786
#
# comment: คุณภาพดีเกินราคา ต้องสั่งอีกครับ
# actual: 5
# predicted: 6.365787851640504
#
# comment: พอใช้ได้
# actual: 1
# predicted: 6.2878899558738635
#
# comment: ส่งของช้ามา รอมาครึ่งเดือนพึ่งจะได้ ถ้าใครรีบไปที่อื่นครับ
# actual: 6
# predicted: 6.209207008644692
#
# comment: สินคเาดีค่ะ ตรงปก ส่งไว แต่หัก1ดาวเพราะสั่งสีฟ้าไปแน่ว่สได้สรขาวมาแทน แต่ว่าไม่มีปัญหาค่ะ สามารถใช้ๆด้ปกติเลย โอเคมาก
# actual: 8
# predicted: 6.20837117172837
#
# comment: สั่งสีขาว แต่ส่งสีชมพูมาแทน ทางร้านไม่ถามก่อน รูปแบบทันสมัย จับถนัดมือ
# actual: 5
# predicted: 6.199244621544316
#
# comment: ดีค่ะ แต่เวลาโดนก็พอสง่ายเกินไปหน่อยค่ะ โดยรวมก็ใช้ง่าย พกพาง่ายสะดวกค่ะ แบตค่อนข้างอึดเลย เวลาเปิดปิดฝาก็ไม่ก๊อกแก๊ง ขนส่งไวค่ะ
# actual: 8
# predicted: 6.171036006391857
#
# comment: สภาพกล่องลำโพงเละเทะมากตั้งเเต่เเกะ ต้องชาร์จลำโพงตลอดเวลาถึงใช้ได้ บลูทูธหลุดบ่อย
# actual: 6
# predicted: 6.135159303924771
#
# comment: ไม่มีสายชาร์ตส่งมาด้วย
# actual: 3
# predicted: 6.046904612786195
#
# comment: ทักทางร้านไม่ตอบ ในรูปตัวอย่างมีสายแจ๊ส ของมาถึงไม่มีไม่มีการบริการดูแล
# actual: 3
# predicted: 6.011607829054924
#
# comment: สินค้ามาตรงปกค่ะ ลูกชอบมากค่ะมีสีสันสวยเวลาพิมพ์ ก็มีสีหลายสี ให้เลือก เวลาพิมพ์ง่ายไม่มีปัญหาในการใช้แป้นพิมพ์ค่ะ
# actual: 6
# predicted: 5.995116561224126
#
# comment: ใส่ซิมแล้วไม่มีสัญญาณ ข้อมูลการลงทะเบียนใช้งานไม่ได้ ร้านค้าตอบช้า
# actual: 7
# predicted: 5.991603392582815
#
# comment: สังเกตดีๆมีรอยเหมือนถูกใช้งานมาแล้วด้วย มันค่อนข้างรู้สึกแย่และผิดหวังน่ะค่ะ แต่ก็ไม่ได้คาดหวังอะไรแต่แรกแล้ว ไม่รู้จะเชื่อมได้รึเปล่า🥲😭
# actual: 7
# predicted: 5.801678272523684
#
# comment: หูฟังได้ยินข้างเดียวไม่ดีเลย การแพคกล่องก็ไม่สมประกอบ ขาด
# actual: 5
# predicted: 5.788277807512664
#
# comment: ได้ของมาวันที่13 วันนี้สั่นค้างแล้วก็ดับไปเลย เปิดไม่ติดอีกเลย ลองชาร์จแล้วก็ไม่มีการตอบสนอง
# actual: 6
# predicted: 5.763770665657618
#
# comment: ได้หูฟังมาข้างเดียว
# actual: 4
# predicted: 5.750312617820803
#
# comment: ลองแล้วโอเค.ไฟติดทุกดวง.รีโมทใใช้ได้โอเคมีถ่านติิดมาแล้วใช้ได้เลย..ไฟสีสันสวยงาม. แพ็คของห่อส่งของดีสินค้าไม่มีเสียหาย.ได้รับของครบ. ตรงตามที่สั่งซื้อ. ขนส่งดีมีโทรแจ้งก่อนเข้ามาส่ง...
# actual: 7
# predicted: 5.727865002355024
#
# comment: สั่งสีดำได้สีน้ำเงิน บอกพนักงานส่งผิด แต่ดูจากรีวิวส่งผิดบ่อยไปนะคะ...
# actual: 5
# predicted: 5.601104097453677
#
# comment: สินค้าตรงปกจัดส่งเร็วมากๆถูกใจคุ้มค่าคุ้มราคาถูกใจครับผมร้านนี้สั่งเลยครับผ จัดส่งไวมากสั่งเลยครับร้านนี้ถูกใจมากๆคุ้มค่าคุ้มราคาราคาไม่แพงด้วย ม
# actual: 6
# predicted: 5.5334524329119565
#
# comment: ของพึ่งได้มาเมื่อวานใช้ตอนเช้าฟังได้แค่ข้างเดียวผมรอของตั้งนานสุดท้ายฟังได้แค่ข้างขวา
# actual: 6
# predicted: 5.4074782318484935
#
# comment: ผมใช้iPhone14 Pro Max 512, มีเคสของcasetify. แม่เหล็กจับดีครับ ดีไซน์เีมาก แต่!!! ชาร์จบ้างไม่ชาร์จบ้าง ถอดเคสมาชาร์จก็เหมือนเดิม ไม่แนะนำให้หวังอะไรมากมายเลยครับ ถือสะว่าเอามาวางโทรศัพท์เฉยๆ ไม่แนะนำให้ซื้อถ้าคุณมีเคสหนา 1ดาวให้การบดีไซน์ นอกนั้นไม่ให้ดาวครับ
# actual: 9
# predicted: 5.400309358512881
#
# comment: รูปลักษณ์สวยงามตามปก แต่ตัวเรือนใหญ่ไปหน่อย การจัดส่งรวดเร็ว แต่ตอบเเช็ทช้ามาก เรื่องการใช้งานขอลองดูก่อนว่าจะใช้ได้ดีขนาดไหน
# actual: 5
# predicted: 5.398828398436722
#
# comment: วัสดุก๊องแก๊งมาก สั่งสีชมพูได้สีฟ้า
# actual: 3
# predicted: 5.380633784236805
#
# comment: ให้สินค้ามาซ้ำและได้ไม่ครบ ไม่ได้จัดสินค้าตามที่สั่ง
# actual: 4
# predicted: 5.283843868974393
#
# comment: ถือว่าดีกว่าที่คิดดลยครับราคาไมาเกินร้อยเสียงกำลังดีไม่ดังไปไม่เบาไป แต่เบสกับเสียงพอใช้ได้ไม่น่าเกรียดครับ
# actual: 6
# predicted: 5.250560421562794
#
# comment: คุ้มค่าราคา
# actual: 1
# predicted: 5.2191274341810105
#
# comment: สวยดีค่ะแต่แบตหมดไวไปหน่อยเล่นไม่ค่อยเป็นด้วยงงๆนิสนึงใส่แล้ววัดไรไม่ค่อยตรงเท่าไหร่หรือเรางงๆไปเองก้อไม่รุ้เหมาะสมแก่ราคาค่ะลูกอยากได้ก้อเลยจัดให้ใช้ดูสักพักว่าจะทนทานมั้ย
# actual: 6
# predicted: 5.028634278341367
#
# comment: แย่ ร้อนมากเวลาชาร์จ มีtype-c แต่ชาร์จออกไม่ได้ไม่รู้มีไว้เพื่ออะไร
# actual: 4
# predicted: 5.006583134714699
#
# comment: สินค้าใช้การไม่ได้
# actual: 3
# predicted: 4.991661215518931
#
# comment: ชอบมากเลยดีไซน์เอยสีเอ่ยดีไปหมดดูเรียบแต่สวยสีดำสวยมากสีเทาก็สวยไว้จะสั่งสีเทาอีกค่ะทรงสวยเสียงดีไม่เจ็บหู
# actual: 7
# predicted: 4.98883643945629
#
# comment: ผิดหวังคนละรุ่นกันชาจไม่ใด้
# actual: 3
# predicted: 4.974130139530362
#
# comment: จากที่ลองใช้มาสักพักดีมากเสียงดีและชัดเสียงไม่แตกเบสหนักฟังเพลงเสียงดีมากมีตำหนินิดหน่อยตรงขอบแต่ไม่เป็นไรแบตทนมากชาร์จ1ครั้งตั้งแต่ได้มาวันแรกจนถึงวันนี้แบตยังเหลืออีก50เปอร์เซ็นต์
# actual: 7
# predicted: 4.807027651136979
#
# comment: เชื่อมต่อได้แค่ข้างเดียวคับ
# actual: 3
# predicted: 4.744472390220006
#
# comment: เสียงเบา​
# actual: 2
# predicted: 4.55314095110574
#
# comment: สินค้าดีมีคุณภาพ
# actual: 2
# predicted: 4.539826730722261
#
# comment: สภาพกล่องเยินนิดนึงแต่สินค้าด้านในยังโอเค เดี๋ยวลองใช้ดูก่อนว่าใช้ได้ปกติมั๊ย
# actual: 4
# predicted: 4.37578243047177
#
# comment: แพ๊คของแย่มาก กล่องสายบุบไปเกือบครึ่ง สั่งครั้งนี้ครั้งเดียวจะไม่สั่งอีกแล้ว
# actual: 6
# predicted: 4.189764554023938
#
# comment: ขนส่งแย่มากครับ
# actual: 3
# predicted: 4.095533829717839
#
# comment: ความคุ้มค่า: ดีสินค้าได้รับแล้วส่งมาจากต่างประเทศไม่มีความเสียหายขนส่งมีความทะนุถนอมดีลองทดลองใช้เดี๋ยวขอทดลองใช้ก่อนนะคะว่าเสียงดีไม่ดีแต่ราคาดีค่ะ
# actual: 6
# predicted: 3.5841462440490552
#
# comment: เครื่องเล็กกว่าที่คิด เสียงไมค์พอใช้ได้ เสียงเพลงไม่ค่อยเท่าไหร่
# actual: 5
# predicted: 2.9865900135422665
#
# comment: ไม่ควรซื้อ
# actual: 1
# predicted: 2.6821180350222105
#
# comment: ปุ่มกดด้านซ้ายเหมือนติดๆอะไรไม่รู้กดไม่ค่อยลง เลื่อนไม่ค่อยไป บลูทูธติดปกติแต่ไวไฟยังต่อไม่ได้เลย ไม่ค่อยคุ้มค่าเงิน
# actual: 7
# predicted: 2.616354984624465
#
# comment: กล่องเล็กถอดเข้าถอดออกยาก โทรไม่ค่อยเสถียร
# actual: 4
# predicted: 2.5730154019969316
#
# comment: รูปทรงเท่ดี วัสดุดี บางครั้งการใช้งานยังหน่วงบ้างนิดหน่อย แต่ก็ถือว่าสมราคา
# actual: 6
# predicted: 2.3786343322382844
#
# comment: สินค้าดี สินค้ามาตรฐานตามราคา จัดส่งสินค้าเรว ดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดีดี ดีดีดีดีดีดีดีดีดีดีดีดี
# actual: 6
# predicted: 2.1339381732403555
#
# comment: ไม่ได้ช่วยอะไรมากเลย
# actual: 1
# predicted: 1.4989823447795088
#
# comment: ไม่ได้ตรงกับความคาดหวัง แต่ก็ไม่แย่มาก
# actual: 0
# predicted: 1.177750398695424
